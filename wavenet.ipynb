# %% [markdown]
# <a href="https://colab.research.google.com/github/shin04/ion-switching/blob/master/wavenet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# expandingしたら下がった(LB : 0.943 > 0.942) (window=[500, 1000, 2000])

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2020.4.5.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.12.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)

# %%
from googleapiclient.discovery import build
import io, os
from googleapiclient.http import MediaIoBaseDownload
from google.colab import auth

auth.authenticate_user()

drive_service = build('drive', 'v3')
results = drive_service.files().list(
        q="name = 'kaggle.json'", fields="files(id)").execute()
kaggle_api_key = results.get('files', [])

filename = "/root/.kaggle/kaggle.json"
os.makedirs(os.path.dirname(filename), exist_ok=True)

request = drive_service.files().get_media(fileId=kaggle_api_key[0]['id'])
fh = io.FileIO(filename, 'wb')
downloader = MediaIoBaseDownload(fh, request)
done = False
while done is False:
    status, done = downloader.next_chunk()
    print("Download %d%%." % int(status.progress() * 100))
os.chmod(filename, 600)
# Out:
# Download 100%.

# %%
# !kaggle datasets download -d cdeotte/data-without-drift
# Out:
# Downloading data-without-drift.zip to /content
#  71% 39.0M/55.0M [00:00<00:00, 81.3MB/s]
# 100% 55.0M/55.0M [00:00<00:00, 112MB/s]

# %%
# !kaggle datasets download -d sggpls/ion-shifted-rfc-proba
# Out:
# Downloading ion-shifted-rfc-proba.zip to /content
#  98% 218M/222M [00:01<00:00, 138MB/s]
# 100% 222M/222M [00:01<00:00, 125MB/s]

# %%
# !kaggle datasets download -d ragnar123/clean-kalman
# Out:
# Downloading clean-kalman.zip to /content
#  92% 73.0M/79.0M [00:01<00:00, 47.1MB/s]
# 100% 79.0M/79.0M [00:01<00:00, 62.9MB/s]

# %%
# !kaggle competitions download -c liverpool-ion-switching
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# Downloading test.csv.zip to /content
#   0% 0.00/9.91M [00:00<?, ?B/s]
# 100% 9.91M/9.91M [00:00<00:00, 163MB/s]
# Downloading sample_submission.csv.zip to /content
#   0% 0.00/4.27M [00:00<?, ?B/s]
# 100% 4.27M/4.27M [00:00<00:00, 39.3MB/s]
# Downloading train.csv.zip to /content
#  64% 17.0M/26.6M [00:00<00:00, 80.4MB/s]
# 100% 26.6M/26.6M [00:00<00:00, 88.7MB/s]

# %%
# !unzip -o '*.zip'
# Out:
# Archive:  train.csv.zip
#   inflating: train.csv
#
# Archive:  test.csv.zip
#   inflating: test.csv
#
# Archive:  clean-kalman.zip
#   inflating: test_clean_kalman.csv
#   inflating: train_clean_kalman.csv
#
# Archive:  ion-shifted-rfc-proba.zip
#   inflating: Y_test_proba.npy
#   inflating: Y_train_proba.npy
#
# Archive:  data-without-drift.zip
#   inflating: test_clean.csv
#   inflating: train_clean.csv
#
# Archive:  sample_submission.csv.zip
#   inflating: sample_submission.csv
#
# 6 archives were successfully processed.

# %%
# !pip install tensorflow_addons
# Out:
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.6/dist-packages (0.8.3)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.6/dist-packages (from tensorflow_addons) (2.7.1)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, Input, Dense, Add, Multiply, BatchNormalization, Activation, Dropout
import pandas as pd
import numpy as np
import random
from tensorflow.keras.callbacks import Callback, LearningRateScheduler
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.keras import losses, models, optimizers
import tensorflow_addons as tfa
import gc
from tqdm import tqdm
from scipy import signal

from sklearn.model_selection import GroupKFold
from sklearn.metrics import f1_score

import warnings
warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 500)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
# configurations and main hyperparammeters
EPOCHS = 110
NNBATCHSIZE = 16
GROUP_BATCH_SIZE = 4000
SEED = 321
LR = 0.001
SPLITS = 5

def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)

# %%
# read data
def read_data():

    train = pd.read_csv('./train_clean_kalman.csv', dtype={'time': np.float32, 'signal': np.float32, 'open_channels':np.int32})
    test  = pd.read_csv('./test_clean_kalman.csv', dtype={'time': np.float32, 'signal': np.float32})
    sub  = pd.read_csv('./sample_submission.csv', dtype={'time': np.float32})
    
    Y_train_proba = np.load("./Y_train_proba.npy")
    Y_test_proba = np.load("./Y_test_proba.npy")
    
    for i in range(11):
        train[f"proba_{i}"] = Y_train_proba[:, i]
        test[f"proba_{i}"] = Y_test_proba[:, i]

    return train, test, sub

# %%
# def batching_10(train, test):
#     # concatenate data
#     batch = 50
#     total_batches = 14
#     train['set'] = 'train'
#     test['set'] = 'test'
#     data = pd.concat([train, test])
#     for i in range(int(total_batches)):
#         data.loc[(data['time'] > i * batch) & (data['time'] <= (i + 1) * batch), 'batch'] = i + 1
#     train = data[data['set'] == 'train']
#     test = data[data['set'] == 'test']
#     train.drop(['set'], inplace = True, axis = 1)
#     test.drop(['set'], inplace = True, axis = 1)
#     del data
#     return train, test

# %%
# create batches of 4000 observations
def batching(df, batch_size):
    df['group'] = df.groupby(df.index//batch_size, sort=False)['signal'].agg(['ngroup']).values
    df['group'] = df['group'].astype(np.uint16)
    return df

# %%
# normalize the data (standard scaler). We can also try other scalers for a better score!
def normalize(train, test):
    train_input_mean = train.signal.mean()
    train_input_sigma = train.signal.std()
    train['signal'] = (train.signal - train_input_mean) / train_input_sigma
    test['signal'] = (test.signal - train_input_mean) / train_input_sigma
    
    return train, test

# %%
def add_category(train, test):
  train["category"] = 0
  test["category"] = 0

  # train segments with more then 9 open channels classes
  train.loc[2000000:2500000-1, 'category'] = 1
  train.loc[4500000:5000000-1, 'category'] = 1

  # test segments with more then 9 open channels classes (potentially)
  test.loc[500000:600000-1, "category"] = 1
  test.loc[700000:800000-1, "category"] = 1
  
  return train, test

# %%
# signal processing features
def calc_gradients(s, n_grads = 4):
    '''
    Calculate gradients for a pandas series. Returns the same number of samples
    '''
    grads = pd.DataFrame()
    
    g = s.values
    for i in range(n_grads):
        g = np.gradient(g)
        grads['grad_' + str(i+1)] = g
        
    return grads

def calc_low_pass(s, n_filts=10):
    '''
    Applies low pass filters to the signal. Left delayed and no delayed
    '''
    wns = np.logspace(-2, -0.3, n_filts)
    
    low_pass = pd.DataFrame()
    x = s.values
    for wn in wns:
        b, a = signal.butter(1, Wn=wn, btype='low')
        zi = signal.lfilter_zi(b, a)
        low_pass['lowpass_lf_' + str('%.4f' %wn)] = signal.lfilter(b, a, x, zi=zi*x[0])[0]
        low_pass['lowpass_ff_' + str('%.4f' %wn)] = signal.filtfilt(b, a, x)
        
    return low_pass

def calc_high_pass(s, n_filts=10):
    '''
    Applies high pass filters to the signal. Left delayed and no delayed
    '''
    wns = np.logspace(-2, -0.1, n_filts)
    
    high_pass = pd.DataFrame()
    x = s.values
    for wn in wns:
        b, a = signal.butter(1, Wn=wn, btype='high')
        zi = signal.lfilter_zi(b, a)
        high_pass['highpass_lf_' + str('%.4f' %wn)] = signal.lfilter(b, a, x, zi=zi*x[0])[0]
        high_pass['highpass_ff_' + str('%.4f' %wn)] = signal.filtfilt(b, a, x)
        
    return high_pass

def calc_ewm(s, windows=[10, 50, 100, 500, 1000]):
    '''
    Calculates exponential weighted functions
    '''
    ewm = pd.DataFrame()
    for w in windows:
        ewm['ewm_mean_' + str(w)] = s.ewm(span=w, min_periods=1).mean()
        ewm['ewm_std_' + str(w)] = s.ewm(span=w, min_periods=1).std()
        
    # add zeros when na values (std)
    ewm = ewm.fillna(value=0)
        
    return ewm


def add_features(s):
    '''
    All calculations together
    '''
    
    gradients = calc_gradients(s)
    low_pass = calc_low_pass(s)
    high_pass = calc_high_pass(s)
    ewm = calc_ewm(s)
    
    return pd.concat([s, gradients, low_pass, high_pass, ewm], axis=1)


# signal_size を考える
# 500000? or 4000?
def divide_and_add_features(s, signal_size=500000):
    '''
    Divide the signal in bags of "signal_size".
    Normalize the data dividing it by 15.0
    '''
    # normalize
    s = s / 15.0
    
    ls = []
    for i in tqdm(range(int(s.shape[0]/signal_size))):
        sig = s[i*signal_size:(i+1)*signal_size].copy().reset_index(drop=True)
        sig_featured = add_features(sig)
        ls.append(sig_featured)
    
    return pd.concat(ls, axis=0)

# %%
# get lead and lags features
def lag_with_pct_change(df, windows):
    for window in windows:    
        df['signal_shift_pos_' + str(window)] = df.groupby('group')['signal'].shift(window).fillna(0)
        df['signal_shift_neg_' + str(window)] = df.groupby('group')['signal'].shift(-1 * window).fillna(0)
    return df

# %%
def calc_roll_stats(df, windows, group='group'):
    '''
    Calculates rolling stats like mean, std, min, max...
    '''
    for i, window in enumerate(windows):
      df[group + 'roll_mean_' + str(window)] = df.groupby(group)['signal'].rolling(window=window, min_periods=window).mean().fillna(0).values
      df[group + 'roll_std_' + str(window)] = df.groupby(group)['signal'].rolling(window=window, min_periods=window).std().fillna(0).values
      df[group + 'roll_min_' + str(window)] = df.groupby(group)['signal'].rolling(window=window, min_periods=window).min().fillna(0).values
      df[group + 'roll_max_' + str(window)] = df.groupby(group)['signal'].rolling(window=window, min_periods=window).max().fillna(0).values
      df[group + 'roll_range' + str(window)] = df[group + 'roll_max_' + str(window)] - df[group + 'roll_min_' + str(window)]

      # df['roll_q10_' + str(window)] = df.groupby('group')['signal'].rolling(window=window, min_periods=1).quantile(0.10).fillna(0).values
      # df['roll_q25_' + str(window)] = df.groupby('group')['signal'].rolling(window=window, min_periods=1).quantile(0.25).fillna(0).values
      # df['roll_q50_' + str(window)] = df.groupby('group')['signal'].rolling(window=window, min_periods=1).quantile(0.50).fillna(0).values
      # df['roll_q75_' + str(window)] = df.groupby('group')['signal'].rolling(window=window, min_periods=1).quantile(0.75).fillna(0).values
      # df['roll_q90_' + str(window)] = df.groupby('group')['signal'].rolling(window=window, min_periods=1).quantile(0.90).fillna(0).values
             
    return df

# %%
def calc_expand_stats(df, group='group'):
  df['expanding_mean'] = df.groupby(group)['signal'].expanding().mean().fillna(0).values
  df['expanding_std'] = df.groupby(group)['signal'].expanding().std().fillna(0).values
  df['expanding_max'] = df.groupby(group)['signal'].expanding().max().fillna(0).values
  df['expanding_min'] = df.groupby(group)['signal'].expanding().min().fillna(0).values
  df['expanding_range'] = df['expanding_max'] - df['expanding_min']
  
  return df

# %%
# main module to run feature engineering. Here you may want to try and add other features and check if your score imporves :).
def run_feat_engineering(df, batch_size):
    # create batches
    df = batching(df, batch_size = batch_size)

    # create leads and lags
    df = lag_with_pct_change(df, np.asarray(range(1, 3), dtype=np.int32))

    # create rolling stats
    df = calc_roll_stats(df, [10, 50, 100, 500, 1000]) # groupごと(4000)
    # df = calc_roll_stats(df, [50000, 100000], group='batch') # batchごと(500000)

    # create expanding stats
    # df = calc_expand_stats(df)

    # create signal ** 2 (this is the new feature)
    df['signal_2'] = df['signal'] ** 2

    return df

# %%
# fillna with the mean and select features for training
def feature_selection(train, test):
    features = [col for col in train.columns if col not in ['index', 'group', 'open_channels', 'time', 'batch']]
    train = train.replace([np.inf, -np.inf], np.nan)
    test = test.replace([np.inf, -np.inf], np.nan)
    for feature in features:
        feature_mean = pd.concat([train[feature], test[feature]], axis = 0).mean()
        train[feature] = train[feature].fillna(feature_mean)
        test[feature] = test[feature].fillna(feature_mean)
    return train, test, features

# %%
# model function (very important, you can try different arquitectures to get a better score. I believe that top public leaderboard is a 1D Conv + RNN style)
def Classifier(shape_):
    
    def cbr(x, out_layer, kernel, stride, dilation):
        x = Conv1D(out_layer, kernel_size=kernel, dilation_rate=dilation, strides=stride, padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        return x
    
    def wave_block(x, filters, kernel_size, n):
        dilation_rates = [2**i for i in range(n)]
        x = Conv1D(filters = filters,
                   kernel_size = 1,
                   padding = 'same')(x)
        res_x = x
        for dilation_rate in dilation_rates:
            tanh_out = Conv1D(filters = filters,
                              kernel_size = kernel_size,
                              padding = 'same', 
                              activation = 'tanh', 
                              dilation_rate = dilation_rate)(x)
            sigm_out = Conv1D(filters = filters,
                              kernel_size = kernel_size,
                              padding = 'same',
                              activation = 'sigmoid', 
                              dilation_rate = dilation_rate)(x)
            x = Multiply()([tanh_out, sigm_out])
            x = Conv1D(filters = filters,
                       kernel_size = 1,
                       padding = 'same')(x)
            res_x = Add()([res_x, x])
        return res_x
    
    inp = Input(shape = (shape_))
    x = cbr(inp, 64, 7, 1, 1)
    x = BatchNormalization()(x)
    x = wave_block(x, 16, 3, 12)
    x = BatchNormalization()(x)
    x = wave_block(x, 32, 3, 8)
    x = BatchNormalization()(x)
    x = wave_block(x, 64, 3, 4)
    x = BatchNormalization()(x)
    x = wave_block(x, 128, 3, 1)
    x = cbr(x, 32, 7, 1, 1)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    out = Dense(11, activation = 'softmax', name = 'out')(x)
    
    model = models.Model(inputs = inp, outputs = out)
    
    opt = Adam(lr = LR)
    opt = tfa.optimizers.SWA(opt)
    model.compile(loss = losses.CategoricalCrossentropy(), optimizer = opt, metrics = ['accuracy'])
    return model

# %%
# function that decrease the learning as epochs increase (i also change this part of the code)
def lr_schedule(epoch):
    if epoch < 30:
        lr = LR
    elif epoch < 40:
        lr = LR / 3
    elif epoch < 50:
        lr = LR / 5
    elif epoch < 60:
        lr = LR / 7
    elif epoch < 70:
        lr = LR / 9
    elif epoch < 80:
        lr = LR / 11
    elif epoch < 90:
        lr = LR / 13
    else:
        lr = LR / 100
    return lr

# %%
# class to get macro f1 score. This is not entirely necessary but it's fun to check f1 score of each epoch (be carefull, if you use this function early stopping callback will not work)
class MacroF1(Callback):
    def __init__(self, model, inputs, targets):
        self.model = model
        self.inputs = inputs
        self.targets = np.argmax(targets, axis = 2).reshape(-1)
        
    def on_epoch_end(self, epoch, logs):
        pred = np.argmax(self.model.predict(self.inputs), axis = 2).reshape(-1)
        score = f1_score(self.targets, pred, average = 'macro')
        print(f'F1 Macro Score: {score:.5f}')

# %%
# main function to perfrom groupkfold cross validation (we have 1000 vectores of 4000 rows and 8 features (columns)). Going to make 5 groups with this subgroups.
def run_cv_model_by_batch(train, test, splits, batch_col, feats, sample_submission, nn_epochs, nn_batch_size):
    
    seed_everything(SEED)
    K.clear_session()
    config = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1,inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=config)
    tf.compat.v1.keras.backend.set_session(sess)
    oof_ = np.zeros((len(train), 11)) # build out of folds matrix with 11 columns, they represent our target variables classes (from 0 to 10)
    preds_ = np.zeros((len(test), 11))
    target = ['open_channels']
    group = train['group']
    kf = GroupKFold(n_splits=5)
    splits = [x for x in kf.split(train, train[target], group)]

    new_splits = []
    for sp in splits:
        new_split = []
        new_split.append(np.unique(group[sp[0]]))
        new_split.append(np.unique(group[sp[1]]))
        new_split.append(sp[1])    
        new_splits.append(new_split)
    # pivot target columns to transform the net to a multiclass classification estructure (you can also leave it in 1 vector with sparsecategoricalcrossentropy loss function)
    tr = pd.concat([pd.get_dummies(train.open_channels), train[['group']]], axis=1)

    tr.columns = ['target_'+str(i) for i in range(11)] + ['group']
    target_cols = ['target_'+str(i) for i in range(11)]
    train_tr = np.array(list(tr.groupby('group').apply(lambda x: x[target_cols].values))).astype(np.float32)
    train = np.array(list(train.groupby('group').apply(lambda x: x[feats].values)))
    test = np.array(list(test.groupby('group').apply(lambda x: x[feats].values)))

    for n_fold, (tr_idx, val_idx, val_orig_idx) in enumerate(new_splits[0:], start=0):
        train_x, train_y = train[tr_idx], train_tr[tr_idx]
        valid_x, valid_y = train[val_idx], train_tr[val_idx]
        print(f'Our training dataset shape is {train_x.shape}')
        print(f'Our validation dataset shape is {valid_x.shape}')

        gc.collect()
        shape_ = (None, train_x.shape[2]) # input is going to be the number of feature we are using (dimension 2 of 0, 1, 2)
        model = Classifier(shape_)
        # using our lr_schedule function
        cb_lr_schedule = LearningRateScheduler(lr_schedule)
        model.fit(train_x,train_y,
                  epochs = nn_epochs,
                  callbacks = [cb_lr_schedule, MacroF1(model, valid_x, valid_y)], # adding custom evaluation metric for each epoch
                  batch_size = nn_batch_size,verbose = 2,
                  validation_data = (valid_x,valid_y))
        preds_f = model.predict(valid_x)
        f1_score_ = f1_score(np.argmax(valid_y, axis=2).reshape(-1),  np.argmax(preds_f, axis=2).reshape(-1), average = 'macro') # need to get the class with the biggest probability
        print(f'Training fold {n_fold + 1} completed. macro f1 score : {f1_score_ :1.5f}')
        preds_f = preds_f.reshape(-1, preds_f.shape[-1])
        oof_[val_orig_idx,:] += preds_f
        te_preds = model.predict(test)
        te_preds = te_preds.reshape(-1, te_preds.shape[-1])           
        preds_ += te_preds / SPLITS
    # calculate the oof macro f1_score
    f1_score_ = f1_score(np.argmax(train_tr, axis = 2).reshape(-1),  np.argmax(oof_, axis = 1), average = 'macro') # axis 2 for the 3 Dimension array and axis 1 for the 2 Domension Array (extracting the best class)
    print(f'Training completed. oof macro f1 score : {f1_score_:1.5f}')
    sample_submission['open_channels'] = np.argmax(preds_, axis = 1).astype(int)
    sample_submission.to_csv('submission_wavenet.csv', index=False, float_format='%.4f')

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        if col!='open_channels':
            col_type = df[col].dtypes
            if col_type in numerics:
                c_min = df[col].min()
                c_max = df[col].max()
                if str(col_type)[:3] == 'int':
                    if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                        df[col] = df[col].astype(np.int8)
                    elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                        df[col] = df[col].astype(np.int16)
                    elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                        df[col] = df[col].astype(np.int32)
                    elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                        df[col] = df[col].astype(np.int64)  
                else:
                    if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                        df[col] = df[col].astype(np.float16)
                    elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                        df[col] = df[col].astype(np.float32)
                    else:
                        df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
print('Reading Data Started...')
train, test, sample_submission = read_data()
train, test = normalize(train, test)
print('Reading and Normalizing Data Completed')
# Out:
# Reading Data Started...
# Reading and Normalizing Data Completed

# %%
print('Creating Features')
print('Feature Engineering Started...')

train, test = add_category(train, test)

# train, test = batching_10(train, test)

train = run_feat_engineering(train, batch_size = GROUP_BATCH_SIZE)
test = run_feat_engineering(test, batch_size = GROUP_BATCH_SIZE)

tr_clean = pd.read_csv('./train_clean.csv', dtype={'time': np.float32, 'signal': np.float32, 'open_channels':np.int32})
ts_clean = pd.read_csv('./test_clean.csv', dtype={'time': np.float32, 'signal': np.float32})
pre_train = divide_and_add_features(tr_clean.signal, signal_size=500000)
pre_test = divide_and_add_features(ts_clean.signal, signal_size=500000)
pre_train.drop('signal', axis=1, inplace=True)
pre_test.drop('signal', axis=1, inplace=True)
pre_train.reset_index(inplace = True, drop = True)
pre_test.reset_index(inplace = True, drop = True)
train = pd.concat([train, pre_train], axis=1)
test = pd.concat([test, pre_test], axis=1)

del pre_train, pre_test, tr_clean, ts_clean
gc.collect

train, test, features = feature_selection(train, test)
print('Feature Engineering Completed...')
# Out:
# Creating Features
# Feature Engineering Started...
# 100%|██████████| 10/10 [00:07<00:00,  1.33it/s]
# 100%|██████████| 4/4 [00:03<00:00,  1.29it/s]
# Feature Engineering Completed...

# %%
print('Reduce memory usage...')
train = reduce_mem_usage(train)
test = reduce_mem_usage(test)
# Out:
# Reduce memory usage...
# Mem. usage decreased to 958.44 Mb (74.4% reduction)
# Mem. usage decreased to 375.75 Mb (74.8% reduction)

# %%
print(f'Training Wavenet model with {SPLITS} folds of GroupKFold Started...')
run_cv_model_by_batch(train, test, SPLITS, 'group', features, sample_submission, EPOCHS, NNBATCHSIZE)
print('Training completed...')
# Out:
# Training Wavenet model with 5 folds of GroupKFold Started...
# Our training dataset shape is (1000, 4000, 97)
# Our validation dataset shape is (250, 4000, 97)
# Epoch 1/110
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# F1 Macro Score: 0.65121
# 63/63 - 41s - loss: 0.7643 - accuracy: 0.7632 - val_loss: 0.9605 - val_accuracy: 0.8593 - lr: 0.0010
# Epoch 2/110
# F1 Macro Score: 0.82238
# 63/63 - 29s - loss: 0.2648 - accuracy: 0.9370 - val_loss: 0.5488 - val_accuracy: 0.9427 - lr: 0.0010
# Epoch 3/110
# F1 Macro Score: 0.86129
# 63/63 - 29s - loss: 0.2049 - accuracy: 0.9506 - val_loss: 0.2714 - val_accuracy: 0.9564 - lr: 0.0010
# Epoch 4/110
# F1 Macro Score: 0.90278
# 63/63 - 29s - loss: 0.1528 - accuracy: 0.9624 - val_loss: 0.1744 - val_accuracy: 0.9618 - lr: 0.0010
# Epoch 5/110
# F1 Macro Score: 0.92172
# 63/63 - 29s - loss: 0.1411 - accuracy: 0.9640 - val_loss: 0.1508 - val_accuracy: 0.9634 - lr: 0.0010
# Epoch 6/110
# F1 Macro Score: 0.93538
# 63/63 - 29s - loss: 0.1331 - accuracy: 0.9649 - val_loss: 0.1218 - val_accuracy: 0.9656 - lr: 0.0010
# Epoch 7/110
# F1 Macro Score: 0.93655
# 63/63 - 29s - loss: 0.1258 - accuracy: 0.9656 - val_loss: 0.1123 - val_accuracy: 0.9661 - lr: 0.0010
# Epoch 8/110
# F1 Macro Score: 0.92394
# 63/63 - 29s - loss: 0.1239 - accuracy: 0.9657 - val_loss: 0.1425 - val_accuracy: 0.9589 - lr: 0.0010
# Epoch 9/110
# F1 Macro Score: 0.93648
# 63/63 - 29s - loss: 0.1221 - accuracy: 0.9658 - val_loss: 0.1124 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 10/110
# F1 Macro Score: 0.93663
# 63/63 - 29s - loss: 0.1203 - accuracy: 0.9660 - val_loss: 0.1062 - val_accuracy: 0.9660 - lr: 0.0010
# Epoch 11/110
# F1 Macro Score: 0.93664
# 63/63 - 29s - loss: 0.1141 - accuracy: 0.9666 - val_loss: 0.1063 - val_accuracy: 0.9658 - lr: 0.0010
# Epoch 12/110
# F1 Macro Score: 0.93602
# 63/63 - 29s - loss: 0.1112 - accuracy: 0.9667 - val_loss: 0.1086 - val_accuracy: 0.9654 - lr: 0.0010
# Epoch 13/110
# F1 Macro Score: 0.93497
# 63/63 - 29s - loss: 0.1166 - accuracy: 0.9660 - val_loss: 0.1094 - val_accuracy: 0.9656 - lr: 0.0010
# Epoch 14/110
# F1 Macro Score: 0.93713
# 63/63 - 29s - loss: 0.1136 - accuracy: 0.9665 - val_loss: 0.1054 - val_accuracy: 0.9660 - lr: 0.0010
# Epoch 15/110
# F1 Macro Score: 0.93557
# 63/63 - 29s - loss: 0.1098 - accuracy: 0.9667 - val_loss: 0.1051 - val_accuracy: 0.9656 - lr: 0.0010
# Epoch 16/110
# F1 Macro Score: 0.93691
# 63/63 - 29s - loss: 0.1079 - accuracy: 0.9668 - val_loss: 0.1006 - val_accuracy: 0.9663 - lr: 0.0010
# Epoch 17/110
# F1 Macro Score: 0.93634
# 63/63 - 29s - loss: 0.1071 - accuracy: 0.9668 - val_loss: 0.1010 - val_accuracy: 0.9660 - lr: 0.0010
# Epoch 18/110
# F1 Macro Score: 0.93700
# 63/63 - 29s - loss: 0.1070 - accuracy: 0.9666 - val_loss: 0.0981 - val_accuracy: 0.9664 - lr: 0.0010
# Epoch 19/110
# F1 Macro Score: 0.93473
# 63/63 - 29s - loss: 0.1054 - accuracy: 0.9668 - val_loss: 0.1055 - val_accuracy: 0.9653 - lr: 0.0010
# Epoch 20/110
# F1 Macro Score: 0.93639
# 63/63 - 29s - loss: 0.1040 - accuracy: 0.9670 - val_loss: 0.0989 - val_accuracy: 0.9661 - lr: 0.0010
# Epoch 21/110
# F1 Macro Score: 0.93728
# 63/63 - 29s - loss: 0.1026 - accuracy: 0.9670 - val_loss: 0.0990 - val_accuracy: 0.9660 - lr: 0.0010
# Epoch 22/110
# F1 Macro Score: 0.93773
# 63/63 - 29s - loss: 0.1019 - accuracy: 0.9669 - val_loss: 0.0945 - val_accuracy: 0.9666 - lr: 0.0010
# Epoch 23/110
# F1 Macro Score: 0.93669
# 63/63 - 29s - loss: 0.1016 - accuracy: 0.9670 - val_loss: 0.0982 - val_accuracy: 0.9661 - lr: 0.0010
# Epoch 24/110
# F1 Macro Score: 0.93629
# 63/63 - 29s - loss: 0.1006 - accuracy: 0.9672 - val_loss: 0.0983 - val_accuracy: 0.9660 - lr: 0.0010
# Epoch 25/110
# F1 Macro Score: 0.93423
# 63/63 - 29s - loss: 0.0999 - accuracy: 0.9671 - val_loss: 0.1043 - val_accuracy: 0.9649 - lr: 0.0010
# Epoch 26/110
# F1 Macro Score: 0.93691
# 63/63 - 29s - loss: 0.1003 - accuracy: 0.9670 - val_loss: 0.0956 - val_accuracy: 0.9661 - lr: 0.0010
# Epoch 27/110
# F1 Macro Score: 0.93341
# 63/63 - 29s - loss: 0.1008 - accuracy: 0.9669 - val_loss: 0.1055 - val_accuracy: 0.9644 - lr: 0.0010
# Epoch 28/110
# F1 Macro Score: 0.93419
# 63/63 - 29s - loss: 0.1031 - accuracy: 0.9666 - val_loss: 0.1111 - val_accuracy: 0.9642 - lr: 0.0010
# Epoch 29/110
# F1 Macro Score: 0.66319
# 63/63 - 29s - loss: 0.2014 - accuracy: 0.9381 - val_loss: 0.6535 - val_accuracy: 0.7923 - lr: 0.0010
# Epoch 30/110
# F1 Macro Score: 0.79366
# 63/63 - 29s - loss: 0.2178 - accuracy: 0.9362 - val_loss: 0.3112 - val_accuracy: 0.9004 - lr: 0.0010
# Epoch 31/110
# F1 Macro Score: 0.93217
# 63/63 - 29s - loss: 0.1320 - accuracy: 0.9628 - val_loss: 0.1206 - val_accuracy: 0.9636 - lr: 3.3333e-04
# Epoch 32/110
# F1 Macro Score: 0.93520
# 63/63 - 29s - loss: 0.1261 - accuracy: 0.9645 - val_loss: 0.1107 - val_accuracy: 0.9650 - lr: 3.3333e-04
# Epoch 33/110
# F1 Macro Score: 0.93694
# 63/63 - 29s - loss: 0.1198 - accuracy: 0.9652 - val_loss: 0.1059 - val_accuracy: 0.9658 - lr: 3.3333e-04
# Epoch 34/110
# F1 Macro Score: 0.93680
# 63/63 - 29s - loss: 0.1171 - accuracy: 0.9657 - val_loss: 0.1053 - val_accuracy: 0.9659 - lr: 3.3333e-04
# Epoch 35/110
# F1 Macro Score: 0.93723
# 63/63 - 29s - loss: 0.1135 - accuracy: 0.9663 - val_loss: 0.1030 - val_accuracy: 0.9661 - lr: 3.3333e-04
# Epoch 36/110
# F1 Macro Score: 0.93699
# 63/63 - 29s - loss: 0.1121 - accuracy: 0.9665 - val_loss: 0.1027 - val_accuracy: 0.9660 - lr: 3.3333e-04
# Epoch 37/110
# F1 Macro Score: 0.93727
# 63/63 - 29s - loss: 0.1100 - accuracy: 0.9668 - val_loss: 0.1008 - val_accuracy: 0.9662 - lr: 3.3333e-04
# Epoch 38/110
# F1 Macro Score: 0.93730
# 63/63 - 29s - loss: 0.1094 - accuracy: 0.9667 - val_loss: 0.1002 - val_accuracy: 0.9662 - lr: 3.3333e-04
# Epoch 39/110
# F1 Macro Score: 0.93750
# 63/63 - 29s - loss: 0.1081 - accuracy: 0.9669 - val_loss: 0.0998 - val_accuracy: 0.9663 - lr: 3.3333e-04
# Epoch 40/110
# F1 Macro Score: 0.93747
# 63/63 - 29s - loss: 0.1080 - accuracy: 0.9668 - val_loss: 0.0988 - val_accuracy: 0.9663 - lr: 3.3333e-04
# Epoch 41/110
# F1 Macro Score: 0.93749
# 63/63 - 29s - loss: 0.1066 - accuracy: 0.9670 - val_loss: 0.0990 - val_accuracy: 0.9663 - lr: 2.0000e-04
# Epoch 42/110
# F1 Macro Score: 0.93579
# 63/63 - 29s - loss: 0.1073 - accuracy: 0.9669 - val_loss: 0.1013 - val_accuracy: 0.9659 - lr: 2.0000e-04
# Epoch 43/110
# F1 Macro Score: 0.93756
# 63/63 - 29s - loss: 0.1060 - accuracy: 0.9671 - val_loss: 0.0980 - val_accuracy: 0.9664 - lr: 2.0000e-04
# Epoch 44/110
# F1 Macro Score: 0.93775
# 63/63 - 29s - loss: 0.1059 - accuracy: 0.9671 - val_loss: 0.0975 - val_accuracy: 0.9664 - lr: 2.0000e-04
# Epoch 45/110
# F1 Macro Score: 0.93756
# 63/63 - 29s - loss: 0.1069 - accuracy: 0.9669 - val_loss: 0.0972 - val_accuracy: 0.9665 - lr: 2.0000e-04
# Epoch 46/110
# F1 Macro Score: 0.93738
# 63/63 - 29s - loss: 0.1053 - accuracy: 0.9670 - val_loss: 0.0981 - val_accuracy: 0.9663 - lr: 2.0000e-04
# Epoch 47/110
# F1 Macro Score: 0.93763
# 63/63 - 29s - loss: 0.1038 - accuracy: 0.9672 - val_loss: 0.0966 - val_accuracy: 0.9665 - lr: 2.0000e-04
# Epoch 48/110
# F1 Macro Score: 0.93726
# 63/63 - 29s - loss: 0.1035 - accuracy: 0.9672 - val_loss: 0.0977 - val_accuracy: 0.9663 - lr: 2.0000e-04
# Epoch 49/110
# F1 Macro Score: 0.93767
# 63/63 - 29s - loss: 0.1039 - accuracy: 0.9672 - val_loss: 0.0965 - val_accuracy: 0.9666 - lr: 2.0000e-04
# Epoch 50/110
# F1 Macro Score: 0.93694
# 63/63 - 29s - loss: 0.1024 - accuracy: 0.9674 - val_loss: 0.0981 - val_accuracy: 0.9662 - lr: 2.0000e-04
# Epoch 51/110
# F1 Macro Score: 0.93764
# 63/63 - 29s - loss: 0.1033 - accuracy: 0.9672 - val_loss: 0.0960 - val_accuracy: 0.9666 - lr: 1.4286e-04
# Epoch 52/110
# F1 Macro Score: 0.93759
# 63/63 - 29s - loss: 0.1020 - accuracy: 0.9674 - val_loss: 0.0957 - val_accuracy: 0.9665 - lr: 1.4286e-04
# Epoch 53/110
# F1 Macro Score: 0.93763
# 63/63 - 29s - loss: 0.1015 - accuracy: 0.9674 - val_loss: 0.0955 - val_accuracy: 0.9666 - lr: 1.4286e-04
# Epoch 54/110
# F1 Macro Score: 0.93785
# 63/63 - 29s - loss: 0.1013 - accuracy: 0.9674 - val_loss: 0.0948 - val_accuracy: 0.9667 - lr: 1.4286e-04
# Epoch 55/110
# F1 Macro Score: 0.93695
# 63/63 - 29s - loss: 0.1084 - accuracy: 0.9660 - val_loss: 0.0973 - val_accuracy: 0.9663 - lr: 1.4286e-04
# Epoch 56/110
# F1 Macro Score: 0.93769
# 63/63 - 29s - loss: 0.1010 - accuracy: 0.9675 - val_loss: 0.0950 - val_accuracy: 0.9665 - lr: 1.4286e-04
# Epoch 57/110
# F1 Macro Score: 0.93767
# 63/63 - 29s - loss: 0.1009 - accuracy: 0.9674 - val_loss: 0.0951 - val_accuracy: 0.9666 - lr: 1.4286e-04
# Epoch 58/110
# F1 Macro Score: 0.93756
# 63/63 - 29s - loss: 0.1005 - accuracy: 0.9675 - val_loss: 0.0951 - val_accuracy: 0.9666 - lr: 1.4286e-04
# Epoch 59/110
# F1 Macro Score: 0.93756
# 63/63 - 29s - loss: 0.1008 - accuracy: 0.9674 - val_loss: 0.0943 - val_accuracy: 0.9666 - lr: 1.4286e-04
# Epoch 60/110
# F1 Macro Score: 0.93761
# 63/63 - 29s - loss: 0.1008 - accuracy: 0.9674 - val_loss: 0.0947 - val_accuracy: 0.9666 - lr: 1.4286e-04
# Epoch 61/110
# F1 Macro Score: 0.93788
# 63/63 - 29s - loss: 0.1004 - accuracy: 0.9675 - val_loss: 0.0938 - val_accuracy: 0.9667 - lr: 1.1111e-04
# Epoch 62/110
# F1 Macro Score: 0.93802
# 63/63 - 29s - loss: 0.0985 - accuracy: 0.9676 - val_loss: 0.0937 - val_accuracy: 0.9667 - lr: 1.1111e-04
# Epoch 63/110
# F1 Macro Score: 0.93768
# 63/63 - 29s - loss: 0.1006 - accuracy: 0.9674 - val_loss: 0.0944 - val_accuracy: 0.9666 - lr: 1.1111e-04
# Epoch 64/110
# F1 Macro Score: 0.93767
# 63/63 - 29s - loss: 0.0988 - accuracy: 0.9676 - val_loss: 0.0938 - val_accuracy: 0.9666 - lr: 1.1111e-04
# Epoch 65/110
# F1 Macro Score: 0.93776
# 63/63 - 29s - loss: 0.0987 - accuracy: 0.9676 - val_loss: 0.0935 - val_accuracy: 0.9667 - lr: 1.1111e-04
# Epoch 66/110
# F1 Macro Score: 0.93765
# 63/63 - 29s - loss: 0.0988 - accuracy: 0.9676 - val_loss: 0.0937 - val_accuracy: 0.9666 - lr: 1.1111e-04
# Epoch 67/110
# F1 Macro Score: 0.93771
# 63/63 - 29s - loss: 0.0989 - accuracy: 0.9675 - val_loss: 0.0931 - val_accuracy: 0.9667 - lr: 1.1111e-04
# Epoch 68/110
# F1 Macro Score: 0.93771
# 63/63 - 29s - loss: 0.0986 - accuracy: 0.9675 - val_loss: 0.0933 - val_accuracy: 0.9666 - lr: 1.1111e-04
# Epoch 69/110
# F1 Macro Score: 0.93793
# 63/63 - 29s - loss: 0.0981 - accuracy: 0.9676 - val_loss: 0.0928 - val_accuracy: 0.9668 - lr: 1.1111e-04
# Epoch 70/110
# F1 Macro Score: 0.93685
# 63/63 - 29s - loss: 0.0983 - accuracy: 0.9676 - val_loss: 0.0953 - val_accuracy: 0.9664 - lr: 1.1111e-04
# Epoch 71/110
# F1 Macro Score: 0.93806
# 63/63 - 29s - loss: 0.0979 - accuracy: 0.9677 - val_loss: 0.0927 - val_accuracy: 0.9668 - lr: 9.0909e-05
# Epoch 72/110
# F1 Macro Score: 0.93776
# 63/63 - 29s - loss: 0.0976 - accuracy: 0.9677 - val_loss: 0.0926 - val_accuracy: 0.9668 - lr: 9.0909e-05
# Epoch 73/110
# F1 Macro Score: 0.93809
# 63/63 - 29s - loss: 0.0967 - accuracy: 0.9677 - val_loss: 0.0928 - val_accuracy: 0.9668 - lr: 9.0909e-05
# Epoch 74/110
# F1 Macro Score: 0.93826
# 63/63 - 29s - loss: 0.0978 - accuracy: 0.9676 - val_loss: 0.0922 - val_accuracy: 0.9669 - lr: 9.0909e-05
# Epoch 75/110
# F1 Macro Score: 0.93795
# 63/63 - 29s - loss: 0.0979 - accuracy: 0.9675 - val_loss: 0.0927 - val_accuracy: 0.9667 - lr: 9.0909e-05
# Epoch 76/110
# F1 Macro Score: 0.93757
# 63/63 - 29s - loss: 0.0979 - accuracy: 0.9676 - val_loss: 0.0940 - val_accuracy: 0.9665 - lr: 9.0909e-05
# Epoch 77/110
# F1 Macro Score: 0.93816
# 63/63 - 29s - loss: 0.0977 - accuracy: 0.9676 - val_loss: 0.0923 - val_accuracy: 0.9668 - lr: 9.0909e-05
# Epoch 78/110
# F1 Macro Score: 0.93778
# 63/63 - 29s - loss: 0.0974 - accuracy: 0.9676 - val_loss: 0.0928 - val_accuracy: 0.9667 - lr: 9.0909e-05
# Epoch 79/110
# F1 Macro Score: 0.93771
# 63/63 - 29s - loss: 0.0970 - accuracy: 0.9676 - val_loss: 0.0926 - val_accuracy: 0.9667 - lr: 9.0909e-05
# Epoch 80/110
# F1 Macro Score: 0.93797
# 63/63 - 29s - loss: 0.0963 - accuracy: 0.9678 - val_loss: 0.0923 - val_accuracy: 0.9668 - lr: 9.0909e-05
# Epoch 81/110
# F1 Macro Score: 0.93803
# 63/63 - 29s - loss: 0.0956 - accuracy: 0.9679 - val_loss: 0.0917 - val_accuracy: 0.9669 - lr: 7.6923e-05
# Epoch 82/110
# F1 Macro Score: 0.93790
# 63/63 - 29s - loss: 0.0965 - accuracy: 0.9677 - val_loss: 0.0918 - val_accuracy: 0.9669 - lr: 7.6923e-05
# Epoch 83/110
# F1 Macro Score: 0.93819
# 63/63 - 29s - loss: 0.0965 - accuracy: 0.9677 - val_loss: 0.0915 - val_accuracy: 0.9669 - lr: 7.6923e-05
# Epoch 84/110
# F1 Macro Score: 0.93807
# 63/63 - 29s - loss: 0.0977 - accuracy: 0.9674 - val_loss: 0.0914 - val_accuracy: 0.9669 - lr: 7.6923e-05
# Epoch 85/110
# F1 Macro Score: 0.93814
# 63/63 - 29s - loss: 0.0975 - accuracy: 0.9676 - val_loss: 0.0915 - val_accuracy: 0.9669 - lr: 7.6923e-05
# Epoch 86/110
# F1 Macro Score: 0.93779
# 63/63 - 29s - loss: 0.0962 - accuracy: 0.9677 - val_loss: 0.0922 - val_accuracy: 0.9668 - lr: 7.6923e-05
# Epoch 87/110
# F1 Macro Score: 0.93829
# 63/63 - 29s - loss: 0.0957 - accuracy: 0.9678 - val_loss: 0.0911 - val_accuracy: 0.9670 - lr: 7.6923e-05
# Epoch 88/110
# F1 Macro Score: 0.93815
# 63/63 - 29s - loss: 0.0961 - accuracy: 0.9676 - val_loss: 0.0913 - val_accuracy: 0.9669 - lr: 7.6923e-05
# Epoch 89/110
# F1 Macro Score: 0.93784
# 63/63 - 29s - loss: 0.0950 - accuracy: 0.9678 - val_loss: 0.0916 - val_accuracy: 0.9667 - lr: 7.6923e-05
# Epoch 90/110
# F1 Macro Score: 0.93758
# 63/63 - 29s - loss: 0.0957 - accuracy: 0.9677 - val_loss: 0.0922 - val_accuracy: 0.9667 - lr: 7.6923e-05
# Epoch 91/110
# F1 Macro Score: 0.93831
# 63/63 - 29s - loss: 0.0950 - accuracy: 0.9678 - val_loss: 0.0907 - val_accuracy: 0.9670 - lr: 1.0000e-05
# Epoch 92/110
# F1 Macro Score: 0.93826
# 63/63 - 29s - loss: 0.0949 - accuracy: 0.9679 - val_loss: 0.0908 - val_accuracy: 0.9670 - lr: 1.0000e-05
# Epoch 93/110
# F1 Macro Score: 0.93827
# 63/63 - 29s - loss: 0.0944 - accuracy: 0.9679 - val_loss: 0.0906 - val_accuracy: 0.9670 - lr: 1.0000e-05
# Epoch 94/110
# F1 Macro Score: 0.93830
# 63/63 - 29s - loss: 0.0958 - accuracy: 0.9677 - val_loss: 0.0908 - val_accuracy: 0.9670 - lr: 1.0000e-05
# Epoch 95/110
# F1 Macro Score: 0.93829
# 63/63 - 29s - loss: 0.0947 - accuracy: 0.9679 - val_loss: 0.0907 - val_accuracy: 0.9670 - lr: 1.0000e-05
# Epoch 96/110
# F1 Macro Score: 0.93825
# 63/63 - 29s - loss: 0.0954 - accuracy: 0.9678 - val_loss: 0.0907 - val_accuracy: 0.9670 - lr: 1.0000e-05
# Epoch 97/110
# F1 Macro Score: 0.93839
# 63/63 - 29s - loss: 0.0948 - accuracy: 0.9678 - val_loss: 0.0906 - val_accuracy: 0.9670 - lr: 1.0000e-05
# Epoch 98/110
# F1 Macro Score: 0.93822
# 63/63 - 29s - loss: 0.0949 - accuracy: 0.9679 - val_loss: 0.0908 - val_accuracy: 0.9670 - lr: 1.0000e-05
# Epoch 99/110
# F1 Macro Score: 0.93831
# 63/63 - 29s - loss: 0.0952 - accuracy: 0.9678 - val_loss: 0.0907 - val_accuracy: 0.9670 - lr: 1.0000e-05
# Epoch 100/110
# F1 Macro Score: 0.93832
# 63/63 - 29s - loss: 0.0950 - accuracy: 0.9678 - val_loss: 0.0906 - val_accuracy: 0.9670 - lr: 1.0000e-05
# Epoch 101/110
# F1 Macro Score: 0.93837
# 63/63 - 29s - loss: 0.0953 - accuracy: 0.9678 - val_loss: 0.0906 - val_accuracy: 0.9670 - lr: 1.0000e-05
# Epoch 102/110
# F1 Macro Score: 0.93830
# 63/63 - 29s - loss: 0.0955 - accuracy: 0.9677 - val_loss: 0.0906 - val_accuracy: 0.9670 - lr: 1.0000e-05
# Epoch 103/110
# F1 Macro Score: 0.93830
# 63/63 - 29s - loss: 0.0954 - accuracy: 0.9678 - val_loss: 0.0907 - val_accuracy: 0.9670 - lr: 1.0000e-05
# Epoch 104/110
# F1 Macro Score: 0.93832
# 63/63 - 29s - loss: 0.0947 - accuracy: 0.9679 - val_loss: 0.0906 - val_accuracy: 0.9670 - lr: 1.0000e-05
# Epoch 105/110
# F1 Macro Score: 0.93830
# 63/63 - 29s - loss: 0.0944 - accuracy: 0.9679 - val_loss: 0.0906 - val_accuracy: 0.9670 - lr: 1.0000e-05
# Epoch 106/110
# F1 Macro Score: 0.93830
# 63/63 - 29s - loss: 0.0949 - accuracy: 0.9679 - val_loss: 0.0908 - val_accuracy: 0.9670 - lr: 1.0000e-05
# Epoch 107/110
# F1 Macro Score: 0.93833
# 63/63 - 29s - loss: 0.0944 - accuracy: 0.9679 - val_loss: 0.0904 - val_accuracy: 0.9670 - lr: 1.0000e-05
# Epoch 108/110
# F1 Macro Score: 0.93833
# 63/63 - 29s - loss: 0.0949 - accuracy: 0.9679 - val_loss: 0.0905 - val_accuracy: 0.9670 - lr: 1.0000e-05
# Epoch 109/110
# F1 Macro Score: 0.93840
# 63/63 - 29s - loss: 0.0947 - accuracy: 0.9678 - val_loss: 0.0904 - val_accuracy: 0.9670 - lr: 1.0000e-05
# Epoch 110/110
# F1 Macro Score: 0.93833
# 63/63 - 29s - loss: 0.0950 - accuracy: 0.9678 - val_loss: 0.0905 - val_accuracy: 0.9670 - lr: 1.0000e-05
# Training fold 1 completed. macro f1 score : 0.93833
# Our training dataset shape is (1000, 4000, 97)
# Our validation dataset shape is (250, 4000, 97)
# Epoch 1/110
# F1 Macro Score: 0.60995
# 63/63 - 35s - loss: 0.7686 - accuracy: 0.7617 - val_loss: 1.1097 - val_accuracy: 0.8336 - lr: 0.0010
# Epoch 2/110
# F1 Macro Score: 0.81200
# 63/63 - 29s - loss: 0.2551 - accuracy: 0.9420 - val_loss: 0.5600 - val_accuracy: 0.9370 - lr: 0.0010
# Epoch 3/110
# F1 Macro Score: 0.90351
# 63/63 - 29s - loss: 0.1894 - accuracy: 0.9569 - val_loss: 0.2850 - val_accuracy: 0.9592 - lr: 0.0010
# Epoch 4/110
# F1 Macro Score: 0.93197
# 63/63 - 29s - loss: 0.1505 - accuracy: 0.9638 - val_loss: 0.1567 - val_accuracy: 0.9673 - lr: 0.0010
# Epoch 5/110
# F1 Macro Score: 0.93584
# 63/63 - 29s - loss: 0.1413 - accuracy: 0.9643 - val_loss: 0.1229 - val_accuracy: 0.9682 - lr: 0.0010
# Epoch 6/110
# F1 Macro Score: 0.93745
# 63/63 - 29s - loss: 0.1327 - accuracy: 0.9651 - val_loss: 0.1200 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 7/110
# F1 Macro Score: 0.93791
# 63/63 - 29s - loss: 0.1248 - accuracy: 0.9657 - val_loss: 0.1035 - val_accuracy: 0.9689 - lr: 0.0010
# Epoch 8/110
# F1 Macro Score: 0.93913
# 63/63 - 29s - loss: 0.1240 - accuracy: 0.9656 - val_loss: 0.1023 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 9/110
# F1 Macro Score: 0.93855
# 63/63 - 29s - loss: 0.1219 - accuracy: 0.9655 - val_loss: 0.1052 - val_accuracy: 0.9689 - lr: 0.0010
# Epoch 10/110
# F1 Macro Score: 0.92967
# 63/63 - 29s - loss: 0.1203 - accuracy: 0.9655 - val_loss: 0.1351 - val_accuracy: 0.9605 - lr: 0.0010
# Epoch 11/110
# F1 Macro Score: 0.93892
# 63/63 - 29s - loss: 0.1175 - accuracy: 0.9656 - val_loss: 0.0949 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 12/110
# F1 Macro Score: 0.93840
# 63/63 - 29s - loss: 0.1118 - accuracy: 0.9661 - val_loss: 0.0945 - val_accuracy: 0.9691 - lr: 0.0010
# Epoch 13/110
# F1 Macro Score: 0.93865
# 63/63 - 29s - loss: 0.1141 - accuracy: 0.9656 - val_loss: 0.0932 - val_accuracy: 0.9693 - lr: 0.0010
# Epoch 14/110
# F1 Macro Score: 0.93807
# 63/63 - 29s - loss: 0.1125 - accuracy: 0.9659 - val_loss: 0.0955 - val_accuracy: 0.9688 - lr: 0.0010
# Epoch 15/110
# F1 Macro Score: 0.93834
# 63/63 - 29s - loss: 0.1104 - accuracy: 0.9659 - val_loss: 0.0918 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 16/110
# F1 Macro Score: 0.93914
# 63/63 - 29s - loss: 0.1073 - accuracy: 0.9663 - val_loss: 0.0913 - val_accuracy: 0.9693 - lr: 0.0010
# Epoch 17/110
# F1 Macro Score: 0.93547
# 63/63 - 29s - loss: 0.1077 - accuracy: 0.9659 - val_loss: 0.0999 - val_accuracy: 0.9679 - lr: 0.0010
# Epoch 18/110
# F1 Macro Score: 0.93629
# 63/63 - 29s - loss: 0.1073 - accuracy: 0.9659 - val_loss: 0.0990 - val_accuracy: 0.9681 - lr: 0.0010
# Epoch 19/110
# F1 Macro Score: 0.93916
# 63/63 - 29s - loss: 0.1065 - accuracy: 0.9661 - val_loss: 0.0893 - val_accuracy: 0.9694 - lr: 0.0010
# Epoch 20/110
# F1 Macro Score: 0.93753
# 63/63 - 29s - loss: 0.1031 - accuracy: 0.9663 - val_loss: 0.0921 - val_accuracy: 0.9687 - lr: 0.0010
# Epoch 21/110
# F1 Macro Score: 0.93859
# 63/63 - 29s - loss: 0.1044 - accuracy: 0.9660 - val_loss: 0.0902 - val_accuracy: 0.9690 - lr: 0.0010
# Epoch 22/110
# F1 Macro Score: 0.93791
# 63/63 - 29s - loss: 0.1017 - accuracy: 0.9664 - val_loss: 0.0924 - val_accuracy: 0.9687 - lr: 0.0010
# Epoch 23/110
# F1 Macro Score: 0.93702
# 63/63 - 29s - loss: 0.1017 - accuracy: 0.9663 - val_loss: 0.0929 - val_accuracy: 0.9688 - lr: 0.0010
# Epoch 24/110
# F1 Macro Score: 0.93886
# 63/63 - 29s - loss: 0.1005 - accuracy: 0.9665 - val_loss: 0.0871 - val_accuracy: 0.9693 - lr: 0.0010
# Epoch 25/110
# F1 Macro Score: 0.93716
# 63/63 - 29s - loss: 0.1022 - accuracy: 0.9661 - val_loss: 0.0941 - val_accuracy: 0.9684 - lr: 0.0010
# Epoch 26/110
# F1 Macro Score: 0.93841
# 63/63 - 29s - loss: 0.1015 - accuracy: 0.9662 - val_loss: 0.0889 - val_accuracy: 0.9689 - lr: 0.0010
# Epoch 27/110
# F1 Macro Score: 0.93891
# 63/63 - 29s - loss: 0.1001 - accuracy: 0.9664 - val_loss: 0.0895 - val_accuracy: 0.9693 - lr: 0.0010
# Epoch 28/110
# F1 Macro Score: 0.92374
# 63/63 - 29s - loss: 0.0992 - accuracy: 0.9664 - val_loss: 0.1161 - val_accuracy: 0.9617 - lr: 0.0010
# Epoch 29/110
# F1 Macro Score: 0.85323
# 63/63 - 29s - loss: 0.1279 - accuracy: 0.9615 - val_loss: 0.2261 - val_accuracy: 0.9307 - lr: 0.0010
# Epoch 30/110
# F1 Macro Score: 0.93856
# 63/63 - 29s - loss: 0.1128 - accuracy: 0.9651 - val_loss: 0.0927 - val_accuracy: 0.9691 - lr: 0.0010
# Epoch 31/110
# F1 Macro Score: 0.93952
# 63/63 - 29s - loss: 0.1019 - accuracy: 0.9664 - val_loss: 0.0863 - val_accuracy: 0.9696 - lr: 3.3333e-04
# Epoch 32/110
# F1 Macro Score: 0.93950
# 63/63 - 29s - loss: 0.1011 - accuracy: 0.9663 - val_loss: 0.0853 - val_accuracy: 0.9696 - lr: 3.3333e-04
# Epoch 33/110
# F1 Macro Score: 0.93739
# 63/63 - 29s - loss: 0.0995 - accuracy: 0.9664 - val_loss: 0.0895 - val_accuracy: 0.9687 - lr: 3.3333e-04
# Epoch 34/110
# F1 Macro Score: 0.93903
# 63/63 - 29s - loss: 0.0987 - accuracy: 0.9665 - val_loss: 0.0862 - val_accuracy: 0.9694 - lr: 3.3333e-04
# Epoch 35/110
# F1 Macro Score: 0.93943
# 63/63 - 29s - loss: 0.0976 - accuracy: 0.9667 - val_loss: 0.0839 - val_accuracy: 0.9697 - lr: 3.3333e-04
# Epoch 36/110
# F1 Macro Score: 0.93968
# 63/63 - 29s - loss: 0.0967 - accuracy: 0.9667 - val_loss: 0.0839 - val_accuracy: 0.9697 - lr: 3.3333e-04
# Epoch 37/110
# F1 Macro Score: 0.93980
# 63/63 - 29s - loss: 0.0963 - accuracy: 0.9667 - val_loss: 0.0834 - val_accuracy: 0.9697 - lr: 3.3333e-04
# Epoch 38/110
# F1 Macro Score: 0.93857
# 63/63 - 29s - loss: 0.0961 - accuracy: 0.9667 - val_loss: 0.0859 - val_accuracy: 0.9692 - lr: 3.3333e-04
# Epoch 39/110
# F1 Macro Score: 0.93975
# 63/63 - 29s - loss: 0.0954 - accuracy: 0.9668 - val_loss: 0.0831 - val_accuracy: 0.9697 - lr: 3.3333e-04
# Epoch 40/110
# F1 Macro Score: 0.93980
# 63/63 - 29s - loss: 0.0953 - accuracy: 0.9668 - val_loss: 0.0835 - val_accuracy: 0.9697 - lr: 3.3333e-04
# Epoch 41/110
# F1 Macro Score: 0.93932
# 63/63 - 29s - loss: 0.0941 - accuracy: 0.9670 - val_loss: 0.0833 - val_accuracy: 0.9696 - lr: 2.0000e-04
# Epoch 42/110
# F1 Macro Score: 0.93991
# 63/63 - 29s - loss: 0.0948 - accuracy: 0.9669 - val_loss: 0.0824 - val_accuracy: 0.9698 - lr: 2.0000e-04
# Epoch 43/110
# F1 Macro Score: 0.93968
# 63/63 - 29s - loss: 0.0942 - accuracy: 0.9670 - val_loss: 0.0823 - val_accuracy: 0.9698 - lr: 2.0000e-04
# Epoch 44/110
# F1 Macro Score: 0.93972
# 63/63 - 29s - loss: 0.0940 - accuracy: 0.9669 - val_loss: 0.0818 - val_accuracy: 0.9698 - lr: 2.0000e-04
# Epoch 45/110
# F1 Macro Score: 0.94006
# 63/63 - 29s - loss: 0.0945 - accuracy: 0.9669 - val_loss: 0.0819 - val_accuracy: 0.9699 - lr: 2.0000e-04
# Epoch 46/110
# F1 Macro Score: 0.94008
# 63/63 - 29s - loss: 0.0937 - accuracy: 0.9670 - val_loss: 0.0824 - val_accuracy: 0.9698 - lr: 2.0000e-04
# Epoch 47/110
# F1 Macro Score: 0.94002
# 63/63 - 29s - loss: 0.0931 - accuracy: 0.9670 - val_loss: 0.0817 - val_accuracy: 0.9699 - lr: 2.0000e-04
# Epoch 48/110
# F1 Macro Score: 0.93977
# 63/63 - 29s - loss: 0.0930 - accuracy: 0.9671 - val_loss: 0.0822 - val_accuracy: 0.9698 - lr: 2.0000e-04
# Epoch 49/110
# F1 Macro Score: 0.93993
# 63/63 - 29s - loss: 0.0936 - accuracy: 0.9668 - val_loss: 0.0817 - val_accuracy: 0.9699 - lr: 2.0000e-04
# Epoch 50/110
# F1 Macro Score: 0.93960
# 63/63 - 29s - loss: 0.0925 - accuracy: 0.9670 - val_loss: 0.0829 - val_accuracy: 0.9697 - lr: 2.0000e-04
# Epoch 51/110
# F1 Macro Score: 0.93991
# 63/63 - 29s - loss: 0.0924 - accuracy: 0.9672 - val_loss: 0.0814 - val_accuracy: 0.9698 - lr: 1.4286e-04
# Epoch 52/110
# F1 Macro Score: 0.93992
# 63/63 - 29s - loss: 0.0923 - accuracy: 0.9672 - val_loss: 0.0811 - val_accuracy: 0.9699 - lr: 1.4286e-04
# Epoch 53/110
# F1 Macro Score: 0.93969
# 63/63 - 28s - loss: 0.0918 - accuracy: 0.9672 - val_loss: 0.0826 - val_accuracy: 0.9697 - lr: 1.4286e-04
# Epoch 54/110
# F1 Macro Score: 0.93935
# 63/63 - 28s - loss: 0.0921 - accuracy: 0.9670 - val_loss: 0.0828 - val_accuracy: 0.9697 - lr: 1.4286e-04
# Epoch 55/110
# F1 Macro Score: 0.93943
# 63/63 - 28s - loss: 0.0949 - accuracy: 0.9666 - val_loss: 0.0829 - val_accuracy: 0.9696 - lr: 1.4286e-04
# Epoch 56/110
# F1 Macro Score: 0.94014
# 63/63 - 28s - loss: 0.0914 - accuracy: 0.9672 - val_loss: 0.0808 - val_accuracy: 0.9700 - lr: 1.4286e-04
# Epoch 57/110
# F1 Macro Score: 0.94003
# 63/63 - 28s - loss: 0.0914 - accuracy: 0.9672 - val_loss: 0.0808 - val_accuracy: 0.9700 - lr: 1.4286e-04
# Epoch 58/110
# F1 Macro Score: 0.93991
# 63/63 - 28s - loss: 0.0911 - accuracy: 0.9673 - val_loss: 0.0807 - val_accuracy: 0.9700 - lr: 1.4286e-04
# Epoch 59/110
# F1 Macro Score: 0.94014
# 63/63 - 29s - loss: 0.0915 - accuracy: 0.9672 - val_loss: 0.0805 - val_accuracy: 0.9700 - lr: 1.4286e-04
# Epoch 60/110
# F1 Macro Score: 0.94012
# 63/63 - 29s - loss: 0.0911 - accuracy: 0.9674 - val_loss: 0.0814 - val_accuracy: 0.9700 - lr: 1.4286e-04
# Epoch 61/110
# F1 Macro Score: 0.94053
# 63/63 - 29s - loss: 0.0911 - accuracy: 0.9673 - val_loss: 0.0798 - val_accuracy: 0.9702 - lr: 1.1111e-04
# Epoch 62/110
# F1 Macro Score: 0.94049
# 63/63 - 28s - loss: 0.0902 - accuracy: 0.9675 - val_loss: 0.0801 - val_accuracy: 0.9702 - lr: 1.1111e-04
# Epoch 63/110
# F1 Macro Score: 0.94065
# 63/63 - 28s - loss: 0.0911 - accuracy: 0.9674 - val_loss: 0.0799 - val_accuracy: 0.9703 - lr: 1.1111e-04
# Epoch 64/110
# F1 Macro Score: 0.94070
# 63/63 - 28s - loss: 0.0899 - accuracy: 0.9676 - val_loss: 0.0796 - val_accuracy: 0.9703 - lr: 1.1111e-04
# Epoch 65/110
# F1 Macro Score: 0.94054
# 63/63 - 29s - loss: 0.0899 - accuracy: 0.9676 - val_loss: 0.0795 - val_accuracy: 0.9703 - lr: 1.1111e-04
# Epoch 66/110
# F1 Macro Score: 0.93999
# 63/63 - 28s - loss: 0.0898 - accuracy: 0.9676 - val_loss: 0.0814 - val_accuracy: 0.9700 - lr: 1.1111e-04
# Epoch 67/110
# F1 Macro Score: 0.94066
# 63/63 - 28s - loss: 0.0897 - accuracy: 0.9677 - val_loss: 0.0792 - val_accuracy: 0.9704 - lr: 1.1111e-04
# Epoch 68/110
# F1 Macro Score: 0.94085
# 63/63 - 28s - loss: 0.0895 - accuracy: 0.9676 - val_loss: 0.0790 - val_accuracy: 0.9704 - lr: 1.1111e-04
# Epoch 69/110
# F1 Macro Score: 0.93990
# 63/63 - 29s - loss: 0.0892 - accuracy: 0.9677 - val_loss: 0.0801 - val_accuracy: 0.9701 - lr: 1.1111e-04
# Epoch 70/110
# F1 Macro Score: 0.94086
# 63/63 - 28s - loss: 0.0891 - accuracy: 0.9678 - val_loss: 0.0793 - val_accuracy: 0.9705 - lr: 1.1111e-04
# Epoch 71/110
# F1 Macro Score: 0.94073
# 63/63 - 28s - loss: 0.0890 - accuracy: 0.9678 - val_loss: 0.0793 - val_accuracy: 0.9704 - lr: 9.0909e-05
# Epoch 72/110
# F1 Macro Score: 0.94096
# 63/63 - 28s - loss: 0.0890 - accuracy: 0.9679 - val_loss: 0.0790 - val_accuracy: 0.9705 - lr: 9.0909e-05
# Epoch 73/110
# F1 Macro Score: 0.94118
# 63/63 - 28s - loss: 0.0882 - accuracy: 0.9679 - val_loss: 0.0786 - val_accuracy: 0.9706 - lr: 9.0909e-05
# Epoch 74/110
# F1 Macro Score: 0.94086
# 63/63 - 29s - loss: 0.0886 - accuracy: 0.9680 - val_loss: 0.0786 - val_accuracy: 0.9705 - lr: 9.0909e-05
# Epoch 75/110
# F1 Macro Score: 0.94001
# 63/63 - 28s - loss: 0.0890 - accuracy: 0.9678 - val_loss: 0.0800 - val_accuracy: 0.9701 - lr: 9.0909e-05
# Epoch 76/110
# F1 Macro Score: 0.93940
# 63/63 - 28s - loss: 0.0891 - accuracy: 0.9678 - val_loss: 0.0827 - val_accuracy: 0.9698 - lr: 9.0909e-05
# Epoch 77/110
# F1 Macro Score: 0.94099
# 63/63 - 29s - loss: 0.0886 - accuracy: 0.9679 - val_loss: 0.0785 - val_accuracy: 0.9706 - lr: 9.0909e-05
# Epoch 78/110
# F1 Macro Score: 0.94112
# 63/63 - 28s - loss: 0.0882 - accuracy: 0.9680 - val_loss: 0.0783 - val_accuracy: 0.9707 - lr: 9.0909e-05
# Epoch 79/110
# F1 Macro Score: 0.94070
# 63/63 - 29s - loss: 0.0879 - accuracy: 0.9680 - val_loss: 0.0791 - val_accuracy: 0.9705 - lr: 9.0909e-05
# Epoch 80/110
# F1 Macro Score: 0.94118
# 63/63 - 29s - loss: 0.0877 - accuracy: 0.9681 - val_loss: 0.0779 - val_accuracy: 0.9707 - lr: 9.0909e-05
# Epoch 81/110
# F1 Macro Score: 0.94117
# 63/63 - 29s - loss: 0.0871 - accuracy: 0.9682 - val_loss: 0.0789 - val_accuracy: 0.9706 - lr: 7.6923e-05
# Epoch 82/110
# F1 Macro Score: 0.94127
# 63/63 - 28s - loss: 0.0875 - accuracy: 0.9682 - val_loss: 0.0783 - val_accuracy: 0.9707 - lr: 7.6923e-05
# Epoch 83/110
# F1 Macro Score: 0.94138
# 63/63 - 29s - loss: 0.0876 - accuracy: 0.9681 - val_loss: 0.0779 - val_accuracy: 0.9707 - lr: 7.6923e-05
# Epoch 84/110
# F1 Macro Score: 0.94099
# 63/63 - 29s - loss: 0.0878 - accuracy: 0.9682 - val_loss: 0.0784 - val_accuracy: 0.9706 - lr: 7.6923e-05
# Epoch 85/110
# F1 Macro Score: 0.94134
# 63/63 - 29s - loss: 0.0881 - accuracy: 0.9681 - val_loss: 0.0777 - val_accuracy: 0.9708 - lr: 7.6923e-05
# Epoch 86/110
# F1 Macro Score: 0.94151
# 63/63 - 28s - loss: 0.0868 - accuracy: 0.9684 - val_loss: 0.0777 - val_accuracy: 0.9708 - lr: 7.6923e-05
# Epoch 87/110
# F1 Macro Score: 0.94140
# 63/63 - 28s - loss: 0.0867 - accuracy: 0.9684 - val_loss: 0.0775 - val_accuracy: 0.9708 - lr: 7.6923e-05
# Epoch 88/110
# F1 Macro Score: 0.94111
# 63/63 - 28s - loss: 0.0872 - accuracy: 0.9683 - val_loss: 0.0791 - val_accuracy: 0.9705 - lr: 7.6923e-05
# Epoch 89/110
# F1 Macro Score: 0.94073
# 63/63 - 29s - loss: 0.0866 - accuracy: 0.9683 - val_loss: 0.0786 - val_accuracy: 0.9705 - lr: 7.6923e-05
# Epoch 90/110
# F1 Macro Score: 0.94188
# 63/63 - 29s - loss: 0.0871 - accuracy: 0.9683 - val_loss: 0.0775 - val_accuracy: 0.9709 - lr: 7.6923e-05
# Epoch 91/110
# F1 Macro Score: 0.94186
# 63/63 - 28s - loss: 0.0860 - accuracy: 0.9686 - val_loss: 0.0773 - val_accuracy: 0.9710 - lr: 1.0000e-05
# Epoch 92/110
# F1 Macro Score: 0.94172
# 63/63 - 29s - loss: 0.0862 - accuracy: 0.9685 - val_loss: 0.0772 - val_accuracy: 0.9709 - lr: 1.0000e-05
# Epoch 93/110
# F1 Macro Score: 0.94179
# 63/63 - 28s - loss: 0.0858 - accuracy: 0.9685 - val_loss: 0.0771 - val_accuracy: 0.9710 - lr: 1.0000e-05
# Epoch 94/110
# F1 Macro Score: 0.94174
# 63/63 - 29s - loss: 0.0868 - accuracy: 0.9684 - val_loss: 0.0773 - val_accuracy: 0.9709 - lr: 1.0000e-05
# Epoch 95/110
# F1 Macro Score: 0.94190
# 63/63 - 28s - loss: 0.0858 - accuracy: 0.9685 - val_loss: 0.0772 - val_accuracy: 0.9710 - lr: 1.0000e-05
# Epoch 96/110
# F1 Macro Score: 0.94173
# 63/63 - 29s - loss: 0.0865 - accuracy: 0.9684 - val_loss: 0.0772 - val_accuracy: 0.9709 - lr: 1.0000e-05
# Epoch 97/110
# F1 Macro Score: 0.94203
# 63/63 - 29s - loss: 0.0860 - accuracy: 0.9685 - val_loss: 0.0772 - val_accuracy: 0.9710 - lr: 1.0000e-05
# Epoch 98/110
# F1 Macro Score: 0.94163
# 63/63 - 29s - loss: 0.0861 - accuracy: 0.9685 - val_loss: 0.0771 - val_accuracy: 0.9709 - lr: 1.0000e-05
# Epoch 99/110
# F1 Macro Score: 0.94163
# 63/63 - 29s - loss: 0.0864 - accuracy: 0.9685 - val_loss: 0.0772 - val_accuracy: 0.9709 - lr: 1.0000e-05
# Epoch 100/110
# F1 Macro Score: 0.94187
# 63/63 - 28s - loss: 0.0864 - accuracy: 0.9684 - val_loss: 0.0771 - val_accuracy: 0.9710 - lr: 1.0000e-05
# Epoch 101/110
# F1 Macro Score: 0.94168
# 63/63 - 29s - loss: 0.0863 - accuracy: 0.9685 - val_loss: 0.0771 - val_accuracy: 0.9709 - lr: 1.0000e-05
# Epoch 102/110
# F1 Macro Score: 0.94188
# 63/63 - 28s - loss: 0.0863 - accuracy: 0.9685 - val_loss: 0.0772 - val_accuracy: 0.9710 - lr: 1.0000e-05
# Epoch 103/110
# F1 Macro Score: 0.94178
# 63/63 - 29s - loss: 0.0866 - accuracy: 0.9685 - val_loss: 0.0772 - val_accuracy: 0.9710 - lr: 1.0000e-05
# Epoch 104/110
# F1 Macro Score: 0.94173
# 63/63 - 28s - loss: 0.0863 - accuracy: 0.9685 - val_loss: 0.0772 - val_accuracy: 0.9710 - lr: 1.0000e-05
# Epoch 105/110
# F1 Macro Score: 0.94179
# 63/63 - 28s - loss: 0.0860 - accuracy: 0.9685 - val_loss: 0.0771 - val_accuracy: 0.9710 - lr: 1.0000e-05
# Epoch 106/110
# F1 Macro Score: 0.94189
# 63/63 - 28s - loss: 0.0861 - accuracy: 0.9686 - val_loss: 0.0774 - val_accuracy: 0.9710 - lr: 1.0000e-05
# Epoch 107/110
# F1 Macro Score: 0.94183
# 63/63 - 29s - loss: 0.0855 - accuracy: 0.9686 - val_loss: 0.0770 - val_accuracy: 0.9710 - lr: 1.0000e-05
# Epoch 108/110
# F1 Macro Score: 0.94178
# 63/63 - 29s - loss: 0.0863 - accuracy: 0.9685 - val_loss: 0.0771 - val_accuracy: 0.9709 - lr: 1.0000e-05
# Epoch 109/110
# F1 Macro Score: 0.94199
# 63/63 - 29s - loss: 0.0859 - accuracy: 0.9685 - val_loss: 0.0772 - val_accuracy: 0.9710 - lr: 1.0000e-05
# Epoch 110/110
# F1 Macro Score: 0.94156
# 63/63 - 28s - loss: 0.0862 - accuracy: 0.9685 - val_loss: 0.0771 - val_accuracy: 0.9709 - lr: 1.0000e-05
# Training fold 2 completed. macro f1 score : 0.94156
# Our training dataset shape is (1000, 4000, 97)
# Our validation dataset shape is (250, 4000, 97)
# Epoch 1/110
# F1 Macro Score: 0.71333
# 63/63 - 35s - loss: 0.8009 - accuracy: 0.7484 - val_loss: 0.9606 - val_accuracy: 0.8468 - lr: 0.0010
# Epoch 2/110
# F1 Macro Score: 0.90242
# 63/63 - 29s - loss: 0.2535 - accuracy: 0.9407 - val_loss: 0.4581 - val_accuracy: 0.9534 - lr: 0.0010
# Epoch 3/110
# F1 Macro Score: 0.92813
# 63/63 - 29s - loss: 0.1934 - accuracy: 0.9545 - val_loss: 0.2280 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 4/110
# F1 Macro Score: 0.93285
# 63/63 - 29s - loss: 0.1457 - accuracy: 0.9636 - val_loss: 0.1594 - val_accuracy: 0.9661 - lr: 0.0010
# Epoch 5/110
# F1 Macro Score: 0.93465
# 63/63 - 29s - loss: 0.1357 - accuracy: 0.9645 - val_loss: 0.1366 - val_accuracy: 0.9662 - lr: 0.0010
# Epoch 6/110
# F1 Macro Score: 0.93526
# 63/63 - 29s - loss: 0.1296 - accuracy: 0.9651 - val_loss: 0.1139 - val_accuracy: 0.9669 - lr: 0.0010
# Epoch 7/110
# F1 Macro Score: 0.93602
# 63/63 - 29s - loss: 0.1215 - accuracy: 0.9658 - val_loss: 0.1044 - val_accuracy: 0.9677 - lr: 0.0010
# Epoch 8/110
# F1 Macro Score: 0.93510
# 63/63 - 29s - loss: 0.1208 - accuracy: 0.9658 - val_loss: 0.1043 - val_accuracy: 0.9674 - lr: 0.0010
# Epoch 9/110
# F1 Macro Score: 0.93468
# 63/63 - 29s - loss: 0.1171 - accuracy: 0.9659 - val_loss: 0.1054 - val_accuracy: 0.9673 - lr: 0.0010
# Epoch 10/110
# F1 Macro Score: 0.93492
# 63/63 - 29s - loss: 0.1153 - accuracy: 0.9659 - val_loss: 0.1020 - val_accuracy: 0.9670 - lr: 0.0010
# Epoch 11/110
# F1 Macro Score: 0.93559
# 63/63 - 29s - loss: 0.1131 - accuracy: 0.9661 - val_loss: 0.0988 - val_accuracy: 0.9676 - lr: 0.0010
# Epoch 12/110
# F1 Macro Score: 0.93639
# 63/63 - 29s - loss: 0.1097 - accuracy: 0.9662 - val_loss: 0.0976 - val_accuracy: 0.9677 - lr: 0.0010
# Epoch 13/110
# F1 Macro Score: 0.70762
# 63/63 - 29s - loss: 0.1383 - accuracy: 0.9601 - val_loss: 0.2984 - val_accuracy: 0.8979 - lr: 0.0010
# Epoch 14/110
# F1 Macro Score: 0.93200
# 63/63 - 29s - loss: 0.1326 - accuracy: 0.9623 - val_loss: 0.1072 - val_accuracy: 0.9663 - lr: 0.0010
# Epoch 15/110
# F1 Macro Score: 0.93651
# 63/63 - 29s - loss: 0.1119 - accuracy: 0.9661 - val_loss: 0.0955 - val_accuracy: 0.9680 - lr: 0.0010
# Epoch 16/110
# F1 Macro Score: 0.93517
# 63/63 - 29s - loss: 0.1085 - accuracy: 0.9662 - val_loss: 0.0987 - val_accuracy: 0.9669 - lr: 0.0010
# Epoch 17/110
# F1 Macro Score: 0.93692
# 63/63 - 29s - loss: 0.1066 - accuracy: 0.9665 - val_loss: 0.0935 - val_accuracy: 0.9682 - lr: 0.0010
# Epoch 18/110
# F1 Macro Score: 0.93362
# 63/63 - 29s - loss: 0.1054 - accuracy: 0.9664 - val_loss: 0.0985 - val_accuracy: 0.9668 - lr: 0.0010
# Epoch 19/110
# F1 Macro Score: 0.93483
# 63/63 - 29s - loss: 0.1032 - accuracy: 0.9666 - val_loss: 0.0968 - val_accuracy: 0.9673 - lr: 0.0010
# Epoch 20/110
# F1 Macro Score: 0.93640
# 63/63 - 29s - loss: 0.1004 - accuracy: 0.9670 - val_loss: 0.0912 - val_accuracy: 0.9681 - lr: 0.0010
# Epoch 21/110
# F1 Macro Score: 0.93441
# 63/63 - 29s - loss: 0.1020 - accuracy: 0.9665 - val_loss: 0.0949 - val_accuracy: 0.9670 - lr: 0.0010
# Epoch 22/110
# F1 Macro Score: 0.93646
# 63/63 - 29s - loss: 0.1014 - accuracy: 0.9665 - val_loss: 0.0892 - val_accuracy: 0.9683 - lr: 0.0010
# Epoch 23/110
# F1 Macro Score: 0.93707
# 63/63 - 29s - loss: 0.1001 - accuracy: 0.9666 - val_loss: 0.0883 - val_accuracy: 0.9684 - lr: 0.0010
# Epoch 24/110
# F1 Macro Score: 0.93624
# 63/63 - 29s - loss: 0.1000 - accuracy: 0.9667 - val_loss: 0.0922 - val_accuracy: 0.9680 - lr: 0.0010
# Epoch 25/110
# F1 Macro Score: 0.93212
# 63/63 - 29s - loss: 0.0993 - accuracy: 0.9666 - val_loss: 0.0982 - val_accuracy: 0.9667 - lr: 0.0010
# Epoch 26/110
# F1 Macro Score: 0.93582
# 63/63 - 29s - loss: 0.1001 - accuracy: 0.9665 - val_loss: 0.0910 - val_accuracy: 0.9680 - lr: 0.0010
# Epoch 27/110
# F1 Macro Score: 0.93409
# 63/63 - 29s - loss: 0.0987 - accuracy: 0.9666 - val_loss: 0.0957 - val_accuracy: 0.9670 - lr: 0.0010
# Epoch 28/110
# F1 Macro Score: 0.93273
# 63/63 - 29s - loss: 0.0996 - accuracy: 0.9663 - val_loss: 0.1084 - val_accuracy: 0.9656 - lr: 0.0010
# Epoch 29/110
# F1 Macro Score: 0.73583
# 63/63 - 29s - loss: 0.2459 - accuracy: 0.9284 - val_loss: 0.4281 - val_accuracy: 0.8621 - lr: 0.0010
# Epoch 30/110
# F1 Macro Score: 0.92292
# 63/63 - 29s - loss: 0.1328 - accuracy: 0.9612 - val_loss: 0.1197 - val_accuracy: 0.9640 - lr: 0.0010
# Epoch 31/110
# F1 Macro Score: 0.93536
# 63/63 - 29s - loss: 0.1127 - accuracy: 0.9656 - val_loss: 0.1014 - val_accuracy: 0.9674 - lr: 3.3333e-04
# Epoch 32/110
# F1 Macro Score: 0.93550
# 63/63 - 29s - loss: 0.1127 - accuracy: 0.9656 - val_loss: 0.0974 - val_accuracy: 0.9678 - lr: 3.3333e-04
# Epoch 33/110
# F1 Macro Score: 0.93636
# 63/63 - 29s - loss: 0.1104 - accuracy: 0.9657 - val_loss: 0.0954 - val_accuracy: 0.9678 - lr: 3.3333e-04
# Epoch 34/110
# F1 Macro Score: 0.93659
# 63/63 - 29s - loss: 0.1086 - accuracy: 0.9660 - val_loss: 0.0939 - val_accuracy: 0.9681 - lr: 3.3333e-04
# Epoch 35/110
# F1 Macro Score: 0.93615
# 63/63 - 29s - loss: 0.1067 - accuracy: 0.9662 - val_loss: 0.0942 - val_accuracy: 0.9680 - lr: 3.3333e-04
# Epoch 36/110
# F1 Macro Score: 0.93628
# 63/63 - 29s - loss: 0.1060 - accuracy: 0.9662 - val_loss: 0.0935 - val_accuracy: 0.9679 - lr: 3.3333e-04
# Epoch 37/110
# F1 Macro Score: 0.93644
# 63/63 - 28s - loss: 0.1038 - accuracy: 0.9665 - val_loss: 0.0926 - val_accuracy: 0.9679 - lr: 3.3333e-04
# Epoch 38/110
# F1 Macro Score: 0.93669
# 63/63 - 28s - loss: 0.1041 - accuracy: 0.9664 - val_loss: 0.0925 - val_accuracy: 0.9682 - lr: 3.3333e-04
# Epoch 39/110
# F1 Macro Score: 0.93676
# 63/63 - 29s - loss: 0.1033 - accuracy: 0.9665 - val_loss: 0.0912 - val_accuracy: 0.9682 - lr: 3.3333e-04
# Epoch 40/110
# F1 Macro Score: 0.93669
# 63/63 - 29s - loss: 0.1031 - accuracy: 0.9665 - val_loss: 0.0911 - val_accuracy: 0.9682 - lr: 3.3333e-04
# Epoch 41/110
# F1 Macro Score: 0.93655
# 63/63 - 29s - loss: 0.1023 - accuracy: 0.9666 - val_loss: 0.0912 - val_accuracy: 0.9681 - lr: 2.0000e-04
# Epoch 42/110
# F1 Macro Score: 0.93453
# 63/63 - 29s - loss: 0.1028 - accuracy: 0.9665 - val_loss: 0.0946 - val_accuracy: 0.9675 - lr: 2.0000e-04
# Epoch 43/110
# F1 Macro Score: 0.93653
# 63/63 - 29s - loss: 0.1021 - accuracy: 0.9666 - val_loss: 0.0906 - val_accuracy: 0.9681 - lr: 2.0000e-04
# Epoch 44/110
# F1 Macro Score: 0.93644
# 63/63 - 29s - loss: 0.1012 - accuracy: 0.9667 - val_loss: 0.0908 - val_accuracy: 0.9680 - lr: 2.0000e-04
# Epoch 45/110
# F1 Macro Score: 0.93668
# 63/63 - 29s - loss: 0.1016 - accuracy: 0.9666 - val_loss: 0.0903 - val_accuracy: 0.9682 - lr: 2.0000e-04
# Epoch 46/110
# F1 Macro Score: 0.93686
# 63/63 - 29s - loss: 0.1007 - accuracy: 0.9667 - val_loss: 0.0894 - val_accuracy: 0.9682 - lr: 2.0000e-04
# Epoch 47/110
# F1 Macro Score: 0.93713
# 63/63 - 29s - loss: 0.0999 - accuracy: 0.9668 - val_loss: 0.0888 - val_accuracy: 0.9684 - lr: 2.0000e-04
# Epoch 48/110
# F1 Macro Score: 0.93697
# 63/63 - 29s - loss: 0.0995 - accuracy: 0.9668 - val_loss: 0.0891 - val_accuracy: 0.9683 - lr: 2.0000e-04
# Epoch 49/110
# F1 Macro Score: 0.93704
# 63/63 - 29s - loss: 0.0997 - accuracy: 0.9668 - val_loss: 0.0889 - val_accuracy: 0.9683 - lr: 2.0000e-04
# Epoch 50/110
# F1 Macro Score: 0.93699
# 63/63 - 29s - loss: 0.0984 - accuracy: 0.9670 - val_loss: 0.0885 - val_accuracy: 0.9684 - lr: 2.0000e-04
# Epoch 51/110
# F1 Macro Score: 0.93706
# 63/63 - 29s - loss: 0.0990 - accuracy: 0.9669 - val_loss: 0.0881 - val_accuracy: 0.9684 - lr: 1.4286e-04
# Epoch 52/110
# F1 Macro Score: 0.93698
# 63/63 - 29s - loss: 0.0987 - accuracy: 0.9669 - val_loss: 0.0881 - val_accuracy: 0.9684 - lr: 1.4286e-04
# Epoch 53/110
# F1 Macro Score: 0.93690
# 63/63 - 29s - loss: 0.0977 - accuracy: 0.9670 - val_loss: 0.0879 - val_accuracy: 0.9684 - lr: 1.4286e-04
# Epoch 54/110
# F1 Macro Score: 0.93684
# 63/63 - 29s - loss: 0.0981 - accuracy: 0.9669 - val_loss: 0.0882 - val_accuracy: 0.9683 - lr: 1.4286e-04
# Epoch 55/110
# F1 Macro Score: 0.93673
# 63/63 - 29s - loss: 0.1027 - accuracy: 0.9659 - val_loss: 0.0903 - val_accuracy: 0.9682 - lr: 1.4286e-04
# Epoch 56/110
# F1 Macro Score: 0.93728
# 63/63 - 29s - loss: 0.0984 - accuracy: 0.9669 - val_loss: 0.0884 - val_accuracy: 0.9684 - lr: 1.4286e-04
# Epoch 57/110
# F1 Macro Score: 0.93720
# 63/63 - 29s - loss: 0.0981 - accuracy: 0.9669 - val_loss: 0.0878 - val_accuracy: 0.9685 - lr: 1.4286e-04
# Epoch 58/110
# F1 Macro Score: 0.93732
# 63/63 - 29s - loss: 0.0972 - accuracy: 0.9671 - val_loss: 0.0871 - val_accuracy: 0.9686 - lr: 1.4286e-04
# Epoch 59/110
# F1 Macro Score: 0.93704
# 63/63 - 29s - loss: 0.0976 - accuracy: 0.9671 - val_loss: 0.0882 - val_accuracy: 0.9684 - lr: 1.4286e-04
# Epoch 60/110
# F1 Macro Score: 0.93692
# 63/63 - 29s - loss: 0.0978 - accuracy: 0.9669 - val_loss: 0.0877 - val_accuracy: 0.9685 - lr: 1.4286e-04
# Epoch 61/110
# F1 Macro Score: 0.93705
# 63/63 - 29s - loss: 0.0969 - accuracy: 0.9671 - val_loss: 0.0872 - val_accuracy: 0.9685 - lr: 1.1111e-04
# Epoch 62/110
# F1 Macro Score: 0.93716
# 63/63 - 29s - loss: 0.0958 - accuracy: 0.9672 - val_loss: 0.0876 - val_accuracy: 0.9684 - lr: 1.1111e-04
# Epoch 63/110
# F1 Macro Score: 0.93683
# 63/63 - 29s - loss: 0.0972 - accuracy: 0.9670 - val_loss: 0.0877 - val_accuracy: 0.9685 - lr: 1.1111e-04
# Epoch 64/110
# F1 Macro Score: 0.93716
# 63/63 - 29s - loss: 0.0959 - accuracy: 0.9672 - val_loss: 0.0869 - val_accuracy: 0.9686 - lr: 1.1111e-04
# Epoch 65/110
# F1 Macro Score: 0.93713
# 63/63 - 29s - loss: 0.0960 - accuracy: 0.9672 - val_loss: 0.0869 - val_accuracy: 0.9686 - lr: 1.1111e-04
# Epoch 66/110
# F1 Macro Score: 0.93737
# 63/63 - 29s - loss: 0.0960 - accuracy: 0.9671 - val_loss: 0.0865 - val_accuracy: 0.9686 - lr: 1.1111e-04
# Epoch 67/110
# F1 Macro Score: 0.93701
# 63/63 - 29s - loss: 0.0958 - accuracy: 0.9673 - val_loss: 0.0868 - val_accuracy: 0.9685 - lr: 1.1111e-04
# Epoch 68/110
# F1 Macro Score: 0.93729
# 63/63 - 29s - loss: 0.0958 - accuracy: 0.9672 - val_loss: 0.0862 - val_accuracy: 0.9686 - lr: 1.1111e-04
# Epoch 69/110
# F1 Macro Score: 0.93708
# 63/63 - 29s - loss: 0.0952 - accuracy: 0.9673 - val_loss: 0.0870 - val_accuracy: 0.9685 - lr: 1.1111e-04
# Epoch 70/110
# F1 Macro Score: 0.93722
# 63/63 - 29s - loss: 0.0959 - accuracy: 0.9672 - val_loss: 0.0868 - val_accuracy: 0.9686 - lr: 1.1111e-04
# Epoch 71/110
# F1 Macro Score: 0.93690
# 63/63 - 29s - loss: 0.0955 - accuracy: 0.9672 - val_loss: 0.0879 - val_accuracy: 0.9683 - lr: 9.0909e-05
# Epoch 72/110
# F1 Macro Score: 0.93699
# 63/63 - 29s - loss: 0.0955 - accuracy: 0.9672 - val_loss: 0.0870 - val_accuracy: 0.9684 - lr: 9.0909e-05
# Epoch 73/110
# F1 Macro Score: 0.93737
# 63/63 - 29s - loss: 0.0944 - accuracy: 0.9673 - val_loss: 0.0860 - val_accuracy: 0.9686 - lr: 9.0909e-05
# Epoch 74/110
# F1 Macro Score: 0.93668
# 63/63 - 29s - loss: 0.0954 - accuracy: 0.9672 - val_loss: 0.0876 - val_accuracy: 0.9684 - lr: 9.0909e-05
# Epoch 75/110
# F1 Macro Score: 0.93737
# 63/63 - 29s - loss: 0.0957 - accuracy: 0.9671 - val_loss: 0.0859 - val_accuracy: 0.9687 - lr: 9.0909e-05
# Epoch 76/110
# F1 Macro Score: 0.93725
# 63/63 - 29s - loss: 0.0954 - accuracy: 0.9672 - val_loss: 0.0862 - val_accuracy: 0.9686 - lr: 9.0909e-05
# Epoch 77/110
# F1 Macro Score: 0.93721
# 63/63 - 29s - loss: 0.0949 - accuracy: 0.9673 - val_loss: 0.0860 - val_accuracy: 0.9686 - lr: 9.0909e-05
# Epoch 78/110
# F1 Macro Score: 0.93741
# 63/63 - 29s - loss: 0.0949 - accuracy: 0.9673 - val_loss: 0.0855 - val_accuracy: 0.9687 - lr: 9.0909e-05
# Epoch 79/110
# F1 Macro Score: 0.93732
# 63/63 - 29s - loss: 0.0945 - accuracy: 0.9673 - val_loss: 0.0858 - val_accuracy: 0.9686 - lr: 9.0909e-05
# Epoch 80/110
# F1 Macro Score: 0.93747
# 63/63 - 29s - loss: 0.0940 - accuracy: 0.9673 - val_loss: 0.0855 - val_accuracy: 0.9686 - lr: 9.0909e-05
# Epoch 81/110
# F1 Macro Score: 0.93738
# 63/63 - 29s - loss: 0.0936 - accuracy: 0.9674 - val_loss: 0.0856 - val_accuracy: 0.9687 - lr: 7.6923e-05
# Epoch 82/110
# F1 Macro Score: 0.93692
# 63/63 - 29s - loss: 0.0939 - accuracy: 0.9673 - val_loss: 0.0855 - val_accuracy: 0.9686 - lr: 7.6923e-05
# Epoch 83/110
# F1 Macro Score: 0.93719
# 63/63 - 29s - loss: 0.0941 - accuracy: 0.9674 - val_loss: 0.0859 - val_accuracy: 0.9686 - lr: 7.6923e-05
# Epoch 84/110
# F1 Macro Score: 0.93661
# 63/63 - 29s - loss: 0.0956 - accuracy: 0.9670 - val_loss: 0.0878 - val_accuracy: 0.9683 - lr: 7.6923e-05
# Epoch 85/110
# F1 Macro Score: 0.93713
# 63/63 - 29s - loss: 0.0952 - accuracy: 0.9672 - val_loss: 0.0857 - val_accuracy: 0.9687 - lr: 7.6923e-05
# Epoch 86/110
# F1 Macro Score: 0.93732
# 63/63 - 29s - loss: 0.0937 - accuracy: 0.9673 - val_loss: 0.0856 - val_accuracy: 0.9686 - lr: 7.6923e-05
# Epoch 87/110
# F1 Macro Score: 0.93733
# 63/63 - 29s - loss: 0.0940 - accuracy: 0.9673 - val_loss: 0.0857 - val_accuracy: 0.9686 - lr: 7.6923e-05
# Epoch 88/110
# F1 Macro Score: 0.93743
# 63/63 - 29s - loss: 0.0943 - accuracy: 0.9673 - val_loss: 0.0852 - val_accuracy: 0.9687 - lr: 7.6923e-05
# Epoch 89/110
# F1 Macro Score: 0.93702
# 63/63 - 29s - loss: 0.0929 - accuracy: 0.9674 - val_loss: 0.0853 - val_accuracy: 0.9686 - lr: 7.6923e-05
# Epoch 90/110
# F1 Macro Score: 0.93739
# 63/63 - 29s - loss: 0.0939 - accuracy: 0.9673 - val_loss: 0.0850 - val_accuracy: 0.9687 - lr: 7.6923e-05
# Epoch 91/110
# F1 Macro Score: 0.93749
# 63/63 - 29s - loss: 0.0929 - accuracy: 0.9675 - val_loss: 0.0848 - val_accuracy: 0.9687 - lr: 1.0000e-05
# Epoch 92/110
# F1 Macro Score: 0.93761
# 63/63 - 29s - loss: 0.0929 - accuracy: 0.9674 - val_loss: 0.0846 - val_accuracy: 0.9688 - lr: 1.0000e-05
# Epoch 93/110
# F1 Macro Score: 0.93758
# 63/63 - 29s - loss: 0.0925 - accuracy: 0.9675 - val_loss: 0.0845 - val_accuracy: 0.9688 - lr: 1.0000e-05
# Epoch 94/110
# F1 Macro Score: 0.93751
# 63/63 - 29s - loss: 0.0940 - accuracy: 0.9673 - val_loss: 0.0848 - val_accuracy: 0.9688 - lr: 1.0000e-05
# Epoch 95/110
# F1 Macro Score: 0.93756
# 63/63 - 29s - loss: 0.0923 - accuracy: 0.9675 - val_loss: 0.0846 - val_accuracy: 0.9688 - lr: 1.0000e-05
# Epoch 96/110
# F1 Macro Score: 0.93754
# 63/63 - 29s - loss: 0.0932 - accuracy: 0.9674 - val_loss: 0.0845 - val_accuracy: 0.9688 - lr: 1.0000e-05
# Epoch 97/110
# F1 Macro Score: 0.93758
# 63/63 - 29s - loss: 0.0926 - accuracy: 0.9676 - val_loss: 0.0845 - val_accuracy: 0.9688 - lr: 1.0000e-05
# Epoch 98/110
# F1 Macro Score: 0.93762
# 63/63 - 29s - loss: 0.0930 - accuracy: 0.9674 - val_loss: 0.0845 - val_accuracy: 0.9688 - lr: 1.0000e-05
# Epoch 99/110
# F1 Macro Score: 0.93751
# 63/63 - 29s - loss: 0.0937 - accuracy: 0.9674 - val_loss: 0.0845 - val_accuracy: 0.9688 - lr: 1.0000e-05
# Epoch 100/110
# F1 Macro Score: 0.93752
# 63/63 - 29s - loss: 0.0929 - accuracy: 0.9675 - val_loss: 0.0845 - val_accuracy: 0.9688 - lr: 1.0000e-05
# Epoch 101/110
# F1 Macro Score: 0.93757
# 63/63 - 29s - loss: 0.0935 - accuracy: 0.9674 - val_loss: 0.0845 - val_accuracy: 0.9688 - lr: 1.0000e-05
# Epoch 102/110
# F1 Macro Score: 0.93747
# 63/63 - 29s - loss: 0.0935 - accuracy: 0.9674 - val_loss: 0.0846 - val_accuracy: 0.9688 - lr: 1.0000e-05
# Epoch 103/110
# F1 Macro Score: 0.93750
# 63/63 - 29s - loss: 0.0935 - accuracy: 0.9673 - val_loss: 0.0845 - val_accuracy: 0.9688 - lr: 1.0000e-05
# Epoch 104/110
# F1 Macro Score: 0.93753
# 63/63 - 29s - loss: 0.0928 - accuracy: 0.9675 - val_loss: 0.0844 - val_accuracy: 0.9688 - lr: 1.0000e-05
# Epoch 105/110
# F1 Macro Score: 0.93750
# 63/63 - 29s - loss: 0.0926 - accuracy: 0.9675 - val_loss: 0.0845 - val_accuracy: 0.9688 - lr: 1.0000e-05
# Epoch 106/110
# F1 Macro Score: 0.93761
# 63/63 - 29s - loss: 0.0929 - accuracy: 0.9675 - val_loss: 0.0845 - val_accuracy: 0.9688 - lr: 1.0000e-05
# Epoch 107/110
# F1 Macro Score: 0.93758
# 63/63 - 29s - loss: 0.0925 - accuracy: 0.9675 - val_loss: 0.0845 - val_accuracy: 0.9688 - lr: 1.0000e-05
# Epoch 108/110
# F1 Macro Score: 0.93764
# 63/63 - 29s - loss: 0.0930 - accuracy: 0.9675 - val_loss: 0.0844 - val_accuracy: 0.9688 - lr: 1.0000e-05
# Epoch 109/110
# F1 Macro Score: 0.93747
# 63/63 - 29s - loss: 0.0928 - accuracy: 0.9674 - val_loss: 0.0847 - val_accuracy: 0.9687 - lr: 1.0000e-05
# Epoch 110/110
# F1 Macro Score: 0.93760
# 63/63 - 29s - loss: 0.0928 - accuracy: 0.9675 - val_loss: 0.0844 - val_accuracy: 0.9688 - lr: 1.0000e-05
# Training fold 3 completed. macro f1 score : 0.93760
# Our training dataset shape is (1000, 4000, 97)
# Our validation dataset shape is (250, 4000, 97)
# Epoch 1/110
# F1 Macro Score: 0.58973
# 63/63 - 35s - loss: 0.7719 - accuracy: 0.7635 - val_loss: 1.0809 - val_accuracy: 0.7216 - lr: 0.0010
# Epoch 2/110
# F1 Macro Score: 0.88473
# 63/63 - 29s - loss: 0.2373 - accuracy: 0.9437 - val_loss: 0.5772 - val_accuracy: 0.9457 - lr: 0.0010
# Epoch 3/110
# F1 Macro Score: 0.92483
# 63/63 - 29s - loss: 0.1904 - accuracy: 0.9547 - val_loss: 0.2598 - val_accuracy: 0.9614 - lr: 0.0010
# Epoch 4/110
# F1 Macro Score: 0.92908
# ...
# Epoch 110/110
# F1 Macro Score: 0.93864
# 63/63 - 29s - loss: 0.0856 - accuracy: 0.9685 - val_loss: 0.0837 - val_accuracy: 0.9683 - lr: 1.0000e-05
# Training fold 4 completed. macro f1 score : 0.93864
# Our training dataset shape is (1000, 4000, 97)
# Our validation dataset shape is (250, 4000, 97)
# Epoch 1/110
# F1 Macro Score: 0.58612
# 63/63 - 36s - loss: 0.7424 - accuracy: 0.7750 - val_loss: 1.0187 - val_accuracy: 0.8186 - lr: 0.0010
# Epoch 2/110
# F1 Macro Score: 0.88028
# 63/63 - 29s - loss: 0.2358 - accuracy: 0.9467 - val_loss: 0.4610 - val_accuracy: 0.9505 - lr: 0.0010
# Epoch 3/110
# F1 Macro Score: 0.93038
# 63/63 - 29s - loss: 0.1775 - accuracy: 0.9579 - val_loss: 0.2608 - val_accuracy: 0.9636 - lr: 0.0010
# Epoch 4/110
# F1 Macro Score: 0.93474
# 63/63 - 29s - loss: 0.1420 - accuracy: 0.9640 - val_loss: 0.1561 - val_accuracy: 0.9659 - lr: 0.0010
# Epoch 5/110
# F1 Macro Score: 0.93484
# 63/63 - 29s - loss: 0.1339 - accuracy: 0.9648 - val_loss: 0.1302 - val_accuracy: 0.9661 - lr: 0.0010
# Epoch 6/110
# F1 Macro Score: 0.93641
# 63/63 - 29s - loss: 0.1275 - accuracy: 0.9655 - val_loss: 0.1099 - val_accuracy: 0.9668 - lr: 0.0010
# Epoch 7/110
# F1 Macro Score: 0.93151
# 63/63 - 29s - loss: 0.1200 - accuracy: 0.9661 - val_loss: 0.1167 - val_accuracy: 0.9651 - lr: 0.0010
# Epoch 8/110
# F1 Macro Score: 0.93695
# 63/63 - 29s - loss: 0.1189 - accuracy: 0.9661 - val_loss: 0.1040 - val_accuracy: 0.9671 - lr: 0.0010
# Epoch 9/110
# F1 Macro Score: 0.93154
# 63/63 - 29s - loss: 0.1166 - accuracy: 0.9661 - val_loss: 0.1291 - val_accuracy: 0.9638 - lr: 0.0010
# Epoch 10/110
# F1 Macro Score: 0.92735
# 63/63 - 29s - loss: 0.1181 - accuracy: 0.9659 - val_loss: 0.1227 - val_accuracy: 0.9624 - lr: 0.0010
# Epoch 11/110
# F1 Macro Score: 0.93531
# 63/63 - 29s - loss: 0.1120 - accuracy: 0.9664 - val_loss: 0.1001 - val_accuracy: 0.9670 - lr: 0.0010
# Epoch 12/110
# F1 Macro Score: 0.93614
# 63/63 - 29s - loss: 0.1086 - accuracy: 0.9666 - val_loss: 0.0998 - val_accuracy: 0.9669 - lr: 0.0010
# Epoch 13/110
# F1 Macro Score: 0.70323
# 63/63 - 29s - loss: 0.1298 - accuracy: 0.9619 - val_loss: 0.3105 - val_accuracy: 0.8925 - lr: 0.0010
# Epoch 14/110
# F1 Macro Score: 0.92873
# 63/63 - 29s - loss: 0.1559 - accuracy: 0.9564 - val_loss: 0.1308 - val_accuracy: 0.9633 - lr: 0.0010
# Epoch 15/110
# F1 Macro Score: 0.93655
# 63/63 - 29s - loss: 0.1157 - accuracy: 0.9657 - val_loss: 0.1002 - val_accuracy: 0.9671 - lr: 0.0010
# Epoch 16/110
# F1 Macro Score: 0.93665
# 63/63 - 29s - loss: 0.1115 - accuracy: 0.9662 - val_loss: 0.0989 - val_accuracy: 0.9674 - lr: 0.0010
# Epoch 17/110
# F1 Macro Score: 0.93567
# 63/63 - 29s - loss: 0.1095 - accuracy: 0.9664 - val_loss: 0.1010 - val_accuracy: 0.9665 - lr: 0.0010
# Epoch 18/110
# F1 Macro Score: 0.93726
# 63/63 - 29s - loss: 0.1062 - accuracy: 0.9666 - val_loss: 0.0947 - val_accuracy: 0.9674 - lr: 0.0010
# Epoch 19/110
# F1 Macro Score: 0.93710
# 63/63 - 29s - loss: 0.1055 - accuracy: 0.9666 - val_loss: 0.0943 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 20/110
# F1 Macro Score: 0.93752
# 63/63 - 29s - loss: 0.1024 - accuracy: 0.9669 - val_loss: 0.0931 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 21/110
# F1 Macro Score: 0.93645
# 63/63 - 29s - loss: 0.1022 - accuracy: 0.9669 - val_loss: 0.0936 - val_accuracy: 0.9672 - lr: 0.0010
# Epoch 22/110
# F1 Macro Score: 0.93679
# 63/63 - 29s - loss: 0.1048 - accuracy: 0.9664 - val_loss: 0.0931 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 23/110
# F1 Macro Score: 0.93764
# 63/63 - 29s - loss: 0.1015 - accuracy: 0.9668 - val_loss: 0.0906 - val_accuracy: 0.9677 - lr: 0.0010
# Epoch 24/110
# F1 Macro Score: 0.93080
# 63/63 - 29s - loss: 0.1003 - accuracy: 0.9669 - val_loss: 0.1060 - val_accuracy: 0.9644 - lr: 0.0010
# Epoch 25/110
# F1 Macro Score: 0.93549
# 63/63 - 29s - loss: 0.1008 - accuracy: 0.9668 - val_loss: 0.0944 - val_accuracy: 0.9669 - lr: 0.0010
# Epoch 26/110
# F1 Macro Score: 0.93719
# 63/63 - 29s - loss: 0.1003 - accuracy: 0.9668 - val_loss: 0.0920 - val_accuracy: 0.9675 - lr: 0.0010
# Epoch 27/110
# F1 Macro Score: 0.93677
# 63/63 - 29s - loss: 0.0987 - accuracy: 0.9669 - val_loss: 0.0911 - val_accuracy: 0.9674 - lr: 0.0010
# Epoch 28/110
# F1 Macro Score: 0.93629
# 63/63 - 29s - loss: 0.0978 - accuracy: 0.9670 - val_loss: 0.0940 - val_accuracy: 0.9670 - lr: 0.0010
# Epoch 29/110
# F1 Macro Score: 0.49600
# 63/63 - 29s - loss: 0.1215 - accuracy: 0.9608 - val_loss: 1.2515 - val_accuracy: 0.6106 - lr: 0.0010
# Epoch 30/110
# F1 Macro Score: 0.77235
# 63/63 - 29s - loss: 0.1883 - accuracy: 0.9451 - val_loss: 0.3213 - val_accuracy: 0.9082 - lr: 0.0010
# Epoch 31/110
# F1 Macro Score: 0.92629
# 63/63 - 29s - loss: 0.1255 - accuracy: 0.9631 - val_loss: 0.1206 - val_accuracy: 0.9624 - lr: 3.3333e-04
# Epoch 32/110
# F1 Macro Score: 0.93711
# 63/63 - 29s - loss: 0.1192 - accuracy: 0.9647 - val_loss: 0.0985 - val_accuracy: 0.9672 - lr: 3.3333e-04
# Epoch 33/110
# F1 Macro Score: 0.93719
# 63/63 - 29s - loss: 0.1110 - accuracy: 0.9659 - val_loss: 0.0965 - val_accuracy: 0.9674 - lr: 3.3333e-04
# Epoch 34/110
# F1 Macro Score: 0.93731
# 63/63 - 29s - loss: 0.1084 - accuracy: 0.9663 - val_loss: 0.0950 - val_accuracy: 0.9674 - lr: 3.3333e-04
# Epoch 35/110
# F1 Macro Score: 0.93712
# 63/63 - 29s - loss: 0.1059 - accuracy: 0.9666 - val_loss: 0.0944 - val_accuracy: 0.9674 - lr: 3.3333e-04
# Epoch 36/110
# F1 Macro Score: 0.93707
# 63/63 - 29s - loss: 0.1043 - accuracy: 0.9667 - val_loss: 0.0940 - val_accuracy: 0.9674 - lr: 3.3333e-04
# Epoch 37/110
# F1 Macro Score: 0.93753
# 63/63 - 29s - loss: 0.1032 - accuracy: 0.9668 - val_loss: 0.0928 - val_accuracy: 0.9676 - lr: 3.3333e-04
# Epoch 38/110
# F1 Macro Score: 0.93775
# 63/63 - 29s - loss: 0.1029 - accuracy: 0.9668 - val_loss: 0.0916 - val_accuracy: 0.9677 - lr: 3.3333e-04
# Epoch 39/110
# F1 Macro Score: 0.93720
# 63/63 - 29s - loss: 0.1019 - accuracy: 0.9670 - val_loss: 0.0926 - val_accuracy: 0.9675 - lr: 3.3333e-04
# Epoch 40/110
# F1 Macro Score: 0.93765
# 63/63 - 29s - loss: 0.1018 - accuracy: 0.9668 - val_loss: 0.0909 - val_accuracy: 0.9677 - lr: 3.3333e-04
# Epoch 41/110
# F1 Macro Score: 0.93745
# 63/63 - 29s - loss: 0.1005 - accuracy: 0.9670 - val_loss: 0.0911 - val_accuracy: 0.9676 - lr: 2.0000e-04
# Epoch 42/110
# F1 Macro Score: 0.93665
# 63/63 - 29s - loss: 0.1014 - accuracy: 0.9669 - val_loss: 0.0930 - val_accuracy: 0.9674 - lr: 2.0000e-04
# Epoch 43/110
# F1 Macro Score: 0.93771
# 63/63 - 29s - loss: 0.1001 - accuracy: 0.9671 - val_loss: 0.0903 - val_accuracy: 0.9677 - lr: 2.0000e-04
# Epoch 44/110
# F1 Macro Score: 0.93790
# 63/63 - 29s - loss: 0.1000 - accuracy: 0.9670 - val_loss: 0.0903 - val_accuracy: 0.9678 - lr: 2.0000e-04
# Epoch 45/110
# F1 Macro Score: 0.93749
# 63/63 - 29s - loss: 0.1003 - accuracy: 0.9669 - val_loss: 0.0905 - val_accuracy: 0.9677 - lr: 2.0000e-04
# Epoch 46/110
# F1 Macro Score: 0.93792
# 63/63 - 29s - loss: 0.0991 - accuracy: 0.9671 - val_loss: 0.0899 - val_accuracy: 0.9678 - lr: 2.0000e-04
# Epoch 47/110
# F1 Macro Score: 0.93794
# 63/63 - 29s - loss: 0.0986 - accuracy: 0.9671 - val_loss: 0.0894 - val_accuracy: 0.9678 - lr: 2.0000e-04
# Epoch 48/110
# F1 Macro Score: 0.93746
# 63/63 - 29s - loss: 0.0983 - accuracy: 0.9671 - val_loss: 0.0908 - val_accuracy: 0.9675 - lr: 2.0000e-04
# Epoch 49/110
# F1 Macro Score: 0.93773
# 63/63 - 29s - loss: 0.0986 - accuracy: 0.9671 - val_loss: 0.0891 - val_accuracy: 0.9678 - lr: 2.0000e-04
# Epoch 50/110
# F1 Macro Score: 0.93774
# 63/63 - 29s - loss: 0.0968 - accuracy: 0.9673 - val_loss: 0.0890 - val_accuracy: 0.9679 - lr: 2.0000e-04
# Epoch 51/110
# F1 Macro Score: 0.93792
# 63/63 - 29s - loss: 0.0974 - accuracy: 0.9672 - val_loss: 0.0885 - val_accuracy: 0.9679 - lr: 1.4286e-04
# Epoch 52/110
# F1 Macro Score: 0.93800
# 63/63 - 29s - loss: 0.0970 - accuracy: 0.9672 - val_loss: 0.0886 - val_accuracy: 0.9679 - lr: 1.4286e-04
# Epoch 53/110
# F1 Macro Score: 0.93736
# 63/63 - 29s - loss: 0.0966 - accuracy: 0.9673 - val_loss: 0.0891 - val_accuracy: 0.9677 - lr: 1.4286e-04
# Epoch 54/110
# F1 Macro Score: 0.93799
# 63/63 - 29s - loss: 0.0968 - accuracy: 0.9672 - val_loss: 0.0886 - val_accuracy: 0.9679 - lr: 1.4286e-04
# Epoch 55/110
# F1 Macro Score: 0.93758
# 63/63 - 29s - loss: 0.1002 - accuracy: 0.9665 - val_loss: 0.0898 - val_accuracy: 0.9677 - lr: 1.4286e-04
# Epoch 56/110
# F1 Macro Score: 0.93788
# 63/63 - 29s - loss: 0.0961 - accuracy: 0.9674 - val_loss: 0.0888 - val_accuracy: 0.9679 - lr: 1.4286e-04
# Epoch 57/110
# F1 Macro Score: 0.93783
# 63/63 - 29s - loss: 0.0958 - accuracy: 0.9673 - val_loss: 0.0883 - val_accuracy: 0.9679 - lr: 1.4286e-04
# Epoch 58/110
# F1 Macro Score: 0.93718
# 63/63 - 29s - loss: 0.0957 - accuracy: 0.9673 - val_loss: 0.0894 - val_accuracy: 0.9676 - lr: 1.4286e-04
# Epoch 59/110
# F1 Macro Score: 0.93784
# 63/63 - 29s - loss: 0.0963 - accuracy: 0.9673 - val_loss: 0.0881 - val_accuracy: 0.9679 - lr: 1.4286e-04
# Epoch 60/110
# F1 Macro Score: 0.93793
# 63/63 - 29s - loss: 0.0961 - accuracy: 0.9673 - val_loss: 0.0881 - val_accuracy: 0.9679 - lr: 1.4286e-04
# Epoch 61/110
# F1 Macro Score: 0.93802
# 63/63 - 29s - loss: 0.0954 - accuracy: 0.9674 - val_loss: 0.0877 - val_accuracy: 0.9679 - lr: 1.1111e-04
# Epoch 62/110
# F1 Macro Score: 0.93808
# 63/63 - 29s - loss: 0.0948 - accuracy: 0.9673 - val_loss: 0.0879 - val_accuracy: 0.9679 - lr: 1.1111e-04
# Epoch 63/110
# F1 Macro Score: 0.93758
# 63/63 - 29s - loss: 0.0960 - accuracy: 0.9673 - val_loss: 0.0881 - val_accuracy: 0.9678 - lr: 1.1111e-04
# Epoch 64/110
# F1 Macro Score: 0.93786
# 63/63 - 29s - loss: 0.0947 - accuracy: 0.9674 - val_loss: 0.0881 - val_accuracy: 0.9679 - lr: 1.1111e-04
# Epoch 65/110
# F1 Macro Score: 0.93786
# 63/63 - 29s - loss: 0.0946 - accuracy: 0.9675 - val_loss: 0.0876 - val_accuracy: 0.9679 - lr: 1.1111e-04
# Epoch 66/110
# F1 Macro Score: 0.93787
# 63/63 - 29s - loss: 0.0945 - accuracy: 0.9674 - val_loss: 0.0876 - val_accuracy: 0.9678 - lr: 1.1111e-04
# Epoch 67/110
# F1 Macro Score: 0.93785
# 63/63 - 29s - loss: 0.0945 - accuracy: 0.9674 - val_loss: 0.0874 - val_accuracy: 0.9680 - lr: 1.1111e-04
# Epoch 68/110
# F1 Macro Score: 0.93790
# 63/63 - 29s - loss: 0.0941 - accuracy: 0.9675 - val_loss: 0.0874 - val_accuracy: 0.9679 - lr: 1.1111e-04
# Epoch 69/110
# F1 Macro Score: 0.93775
# 63/63 - 29s - loss: 0.0944 - accuracy: 0.9674 - val_loss: 0.0878 - val_accuracy: 0.9679 - lr: 1.1111e-04
# Epoch 70/110
# F1 Macro Score: 0.93796
# 63/63 - 29s - loss: 0.0942 - accuracy: 0.9675 - val_loss: 0.0870 - val_accuracy: 0.9679 - lr: 1.1111e-04
# Epoch 71/110
# F1 Macro Score: 0.93806
# 63/63 - 29s - loss: 0.0940 - accuracy: 0.9674 - val_loss: 0.0872 - val_accuracy: 0.9680 - lr: 9.0909e-05
# Epoch 72/110
# F1 Macro Score: 0.93771
# 63/63 - 29s - loss: 0.0942 - accuracy: 0.9675 - val_loss: 0.0872 - val_accuracy: 0.9679 - lr: 9.0909e-05
# Epoch 73/110
# F1 Macro Score: 0.93806
# 63/63 - 29s - loss: 0.0931 - accuracy: 0.9675 - val_loss: 0.0871 - val_accuracy: 0.9679 - lr: 9.0909e-05
# Epoch 74/110
# F1 Macro Score: 0.93769
# 63/63 - 29s - loss: 0.0941 - accuracy: 0.9674 - val_loss: 0.0869 - val_accuracy: 0.9679 - lr: 9.0909e-05
# Epoch 75/110
# F1 Macro Score: 0.93813
# 63/63 - 29s - loss: 0.0944 - accuracy: 0.9674 - val_loss: 0.0866 - val_accuracy: 0.9680 - lr: 9.0909e-05
# Epoch 76/110
# F1 Macro Score: 0.93790
# 63/63 - 29s - loss: 0.0938 - accuracy: 0.9674 - val_loss: 0.0869 - val_accuracy: 0.9679 - lr: 9.0909e-05
# Epoch 77/110
# F1 Macro Score: 0.93786
# 63/63 - 29s - loss: 0.0939 - accuracy: 0.9674 - val_loss: 0.0869 - val_accuracy: 0.9680 - lr: 9.0909e-05
# Epoch 78/110
# F1 Macro Score: 0.93773
# 63/63 - 29s - loss: 0.0938 - accuracy: 0.9674 - val_loss: 0.0871 - val_accuracy: 0.9679 - lr: 9.0909e-05
# Epoch 79/110
# F1 Macro Score: 0.93824
# 63/63 - 29s - loss: 0.0932 - accuracy: 0.9675 - val_loss: 0.0865 - val_accuracy: 0.9680 - lr: 9.0909e-05
# Epoch 80/110
# F1 Macro Score: 0.93820
# 63/63 - 29s - loss: 0.0927 - accuracy: 0.9675 - val_loss: 0.0866 - val_accuracy: 0.9681 - lr: 9.0909e-05
# Epoch 81/110
# F1 Macro Score: 0.93805
# 63/63 - 29s - loss: 0.0922 - accuracy: 0.9676 - val_loss: 0.0864 - val_accuracy: 0.9680 - lr: 7.6923e-05
# Epoch 82/110
# F1 Macro Score: 0.93818
# 63/63 - 29s - loss: 0.0930 - accuracy: 0.9675 - val_loss: 0.0866 - val_accuracy: 0.9680 - lr: 7.6923e-05
# Epoch 83/110
# F1 Macro Score: 0.93816
# 63/63 - 29s - loss: 0.0932 - accuracy: 0.9675 - val_loss: 0.0862 - val_accuracy: 0.9681 - lr: 7.6923e-05
# Epoch 84/110
# F1 Macro Score: 0.93797
# 63/63 - 29s - loss: 0.0932 - accuracy: 0.9674 - val_loss: 0.0867 - val_accuracy: 0.9679 - lr: 7.6923e-05
# Epoch 85/110
# F1 Macro Score: 0.93710
# 63/63 - 29s - loss: 0.0932 - accuracy: 0.9675 - val_loss: 0.0878 - val_accuracy: 0.9676 - lr: 7.6923e-05
# Epoch 86/110
# F1 Macro Score: 0.93820
# 63/63 - 29s - loss: 0.0921 - accuracy: 0.9676 - val_loss: 0.0862 - val_accuracy: 0.9681 - lr: 7.6923e-05
# Epoch 87/110
# F1 Macro Score: 0.93803
# 63/63 - 29s - loss: 0.0922 - accuracy: 0.9677 - val_loss: 0.0862 - val_accuracy: 0.9680 - lr: 7.6923e-05
# Epoch 88/110
# F1 Macro Score: 0.93801
# 63/63 - 29s - loss: 0.0925 - accuracy: 0.9675 - val_loss: 0.0863 - val_accuracy: 0.9679 - lr: 7.6923e-05
# Epoch 89/110
# F1 Macro Score: 0.93758
# 63/63 - 29s - loss: 0.0918 - accuracy: 0.9676 - val_loss: 0.0874 - val_accuracy: 0.9678 - lr: 7.6923e-05
# Epoch 90/110
# F1 Macro Score: 0.93777
# 63/63 - 29s - loss: 0.0926 - accuracy: 0.9675 - val_loss: 0.0864 - val_accuracy: 0.9679 - lr: 7.6923e-05
# Epoch 91/110
# F1 Macro Score: 0.93823
# 63/63 - 29s - loss: 0.0915 - accuracy: 0.9677 - val_loss: 0.0858 - val_accuracy: 0.9681 - lr: 1.0000e-05
# Epoch 92/110
# F1 Macro Score: 0.93808
# 63/63 - 29s - loss: 0.0917 - accuracy: 0.9676 - val_loss: 0.0858 - val_accuracy: 0.9680 - lr: 1.0000e-05
# Epoch 93/110
# F1 Macro Score: 0.93823
# 63/63 - 29s - loss: 0.0912 - accuracy: 0.9677 - val_loss: 0.0857 - val_accuracy: 0.9681 - lr: 1.0000e-05
# Epoch 94/110
# F1 Macro Score: 0.93811
# 63/63 - 29s - loss: 0.0925 - accuracy: 0.9676 - val_loss: 0.0858 - val_accuracy: 0.9680 - lr: 1.0000e-05
# Epoch 95/110
# F1 Macro Score: 0.93824
# 63/63 - 29s - loss: 0.0913 - accuracy: 0.9677 - val_loss: 0.0857 - val_accuracy: 0.9681 - lr: 1.0000e-05
# Epoch 96/110
# F1 Macro Score: 0.93821
# 63/63 - 29s - loss: 0.0920 - accuracy: 0.9677 - val_loss: 0.0857 - val_accuracy: 0.9681 - lr: 1.0000e-05
# Epoch 97/110
# F1 Macro Score: 0.93822
# 63/63 - 29s - loss: 0.0916 - accuracy: 0.9677 - val_loss: 0.0857 - val_accuracy: 0.9681 - lr: 1.0000e-05
# Epoch 98/110
# F1 Macro Score: 0.93825
# 63/63 - 29s - loss: 0.0918 - accuracy: 0.9677 - val_loss: 0.0857 - val_accuracy: 0.9681 - lr: 1.0000e-05
# Epoch 99/110
# F1 Macro Score: 0.93821
# 63/63 - 29s - loss: 0.0926 - accuracy: 0.9676 - val_loss: 0.0857 - val_accuracy: 0.9681 - lr: 1.0000e-05
# Epoch 100/110
# F1 Macro Score: 0.93826
# 63/63 - 29s - loss: 0.0917 - accuracy: 0.9677 - val_loss: 0.0857 - val_accuracy: 0.9681 - lr: 1.0000e-05
# Epoch 101/110
# F1 Macro Score: 0.93820
# 63/63 - 29s - loss: 0.0918 - accuracy: 0.9676 - val_loss: 0.0857 - val_accuracy: 0.9681 - lr: 1.0000e-05
# Epoch 102/110
# F1 Macro Score: 0.93825
# 63/63 - 29s - loss: 0.0920 - accuracy: 0.9676 - val_loss: 0.0856 - val_accuracy: 0.9681 - lr: 1.0000e-05
# Epoch 103/110
# F1 Macro Score: 0.93829
# 63/63 - 29s - loss: 0.0921 - accuracy: 0.9675 - val_loss: 0.0857 - val_accuracy: 0.9681 - lr: 1.0000e-05
# Epoch 104/110
# F1 Macro Score: 0.93827
# 63/63 - 29s - loss: 0.0917 - accuracy: 0.9677 - val_loss: 0.0856 - val_accuracy: 0.9681 - lr: 1.0000e-05
# Epoch 105/110
# F1 Macro Score: 0.93825
# 63/63 - 29s - loss: 0.0913 - accuracy: 0.9677 - val_loss: 0.0857 - val_accuracy: 0.9681 - lr: 1.0000e-05
# Epoch 106/110
# F1 Macro Score: 0.93826
# 63/63 - 29s - loss: 0.0919 - accuracy: 0.9676 - val_loss: 0.0856 - val_accuracy: 0.9681 - lr: 1.0000e-05
# Epoch 107/110
# F1 Macro Score: 0.93825
# 63/63 - 29s - loss: 0.0914 - accuracy: 0.9677 - val_loss: 0.0857 - val_accuracy: 0.9681 - lr: 1.0000e-05
# Epoch 108/110
# F1 Macro Score: 0.93825
# 63/63 - 29s - loss: 0.0916 - accuracy: 0.9677 - val_loss: 0.0856 - val_accuracy: 0.9681 - lr: 1.0000e-05
# Epoch 109/110
# F1 Macro Score: 0.93826
# 63/63 - 29s - loss: 0.0913 - accuracy: 0.9677 - val_loss: 0.0856 - val_accuracy: 0.9681 - lr: 1.0000e-05
# Epoch 110/110
# F1 Macro Score: 0.93832
# 63/63 - 29s - loss: 0.0916 - accuracy: 0.9678 - val_loss: 0.0856 - val_accuracy: 0.9681 - lr: 1.0000e-05
# Training fold 5 completed. macro f1 score : 0.93832
# Training completed. oof macro f1 score : 0.93891
# Training completed...

# %%
# !kaggle competitions submit -f './submission_wavenet.csv' -m 'wavenet' liverpool-ion-switching
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# 100% 21.0M/21.0M [00:05<00:00, 4.17MB/s]
# Successfully submitted to University of Liverpool - Ion Switching

# %% [markdown]
# training with clean_kalman
# > Training completed. oof macro f1 score : 0.93940
# > LB : 0.940
#
# clean_kalman
# add category
# add 20shifted
# > Training completed. oof macro f1 score : 0.93941
# > LB : 0.940
#
# clean_kalman
# add category
# add 20shifted
# add target encoding(group)
# > Training completed. oof macro f1 score : 0.93880
# > LB : 0.653
#
# clean_kalman + add category + add 20shifted
# > Training completed. oof macro f1 score : 0.93953
# > LB : 0.942
#
# clean_kalman + add category + add 20shifted + target encording(category)
# >　Training completed. oof macro f1 score : 0.93842
# >　LB : 0.941
